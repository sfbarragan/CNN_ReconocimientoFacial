# %%
#Importamos las librerías correspondientes
# Importamos la librería ImageDataGenerator,
from keras.preprocessing.image import ImageDataGenerator
# Importamos la librería  array_to_img, img_to_array, load_img
from tensorflow.keras.utils import array_to_img, img_to_array, load_img
# Importamos la librería glob
import glob
# Importamos la librería plt
import matplotlib.pyplot as plt
# Importamos la librería os
import os
# Configuramos el ambiente
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#Importamos la libreria shutil
import shutil
#Importamos la libreria random
import random
# Importamos la librería io 
from skimage import io
# Importamos open cv
import cv2
# Importamos remove de la libreria rembg
from rembg import remove

# %% [markdown]
# ## Descripción del dataset
#
# El presente dataset incorpora fotos de los estudiantes de sexto semestre de la carrera de Ingenieria en tecnologias de la información, cuyo objetivo es la aplicación de las mismas para realizar un reconocimiento facial identificando el nombre de cada uno de los participantes.
#
# Dentro del conjunto de imagenes podemos identificar que se centran en el uso de los formatos jpg, png, jpeg. El esquema de colores utilizado por las imagenes es RGB. Sus dimenciones preestablecidas se encuentran en 5 x 5 cm, siendo imagenes que enfocan los 3 diferentes perfiles del rostro de una persona.
#
# Las clases objetivo con las que dispone el dataset son las siguientes:
# 'Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'HectorCedeño', 'JhonZambrano', 'JordanEspinosa', 'JorgeBorrero', 'JoseRuiz', 'LeonardoBorja', 'LucioCarlos', 'MasacheFernando', 'MelanyLopez', 'MosqueraLucy', 'NatalyAcosta', 'OlallaLuis', 'ParragaMariaJose', 'PauteKevin', 'RaymondDavila', 'RivasSelena', 'SalazarJohana', 'SolanoWilmer', 'SolorzanoBryan'

# %% [markdown]
# ## Descripción del problema
# Este dataset contiene varios parámetros/características en donde se requiere realizar un reconocimiento facial de una persona por medio de la predicción basada en imágenes. Cabe mencionar que por cada persona se extrajo un total de tres imagenes de los perfiles del rostro, para el respectivo entrenamiento del modelo que consta del lado frontal, lado derecho y lado izquierdo del rostro de la persona.

# %% [markdown]
# ## Carga del dataset

# %%
# Definimos la ruta del dataset
folder = 'C:\IAU3/PROYECTOIA-U3/'

# %%
#Se observa los nombres de las carpetas
nombres = os.listdir(folder)
# Imprimimos los nombres
print(nombres)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'HectorCedenio', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MasacheFernando', 'MelanyLopez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMariaJose', 'PauteKevin', 'Raymond Davila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']

# %%
#Creamos un bucle que se ejecutara hasta que se hayan leido todas las clases
for class_name in nombres:
    # Creamos una ruta especifica con el nombre de la clase
    cur_path = folder + "/" + class_name
    # Obtenemos los elementos de la ruta indicada
    elements = os.listdir(cur_path)
    #Definimos un bucle que lea todos los elementos
    for element in elements:
        # Imprimimos la acción realizada
        print("Copying Image - {} in Fotos_Augmented/{}".format(element, class_name))
        # Definimos la ruta de origen de los elementos
        src = os.path.join(folder + "/" + class_name, element) # origen
        # Definimos la ruta de destino de los elementos
        dst = os.path.join("C:\IAU3/Fotos_Augmented/" + class_name, element) 
        
        
        # Realizamos la copia de las fotos
        shutil.copy(src, dst)
# Out:
# Copying Image - L00376418_1.jpg in Fotos_Augmented/Ariel Chabla
# Copying Image - L00376418_2.jpg in Fotos_Augmented/Ariel Chabla
# Copying Image - L00376418_3.jpg in Fotos_Augmented/Ariel Chabla
# Copying Image - L00376418_4.jpg in Fotos_Augmented/Ariel Chabla
# Copying Image - L00376418_5.jpg in Fotos_Augmented/Ariel Chabla
# Copying Image - L00376418_6.jpg in Fotos_Augmented/Ariel Chabla
# Copying Image - L00376418_7.jpg in Fotos_Augmented/Ariel Chabla
# Copying Image - L00376418_8.jpg in Fotos_Augmented/Ariel Chabla
# Copying Image - L00385770_1.png in Fotos_Augmented/ArroboMercy
# Copying Image - L00385770_2.png in Fotos_Augmented/ArroboMercy
# Copying Image - L00385770_3.png in Fotos_Augmented/ArroboMercy
# Copying Image - L00385770_4.png in Fotos_Augmented/ArroboMercy
# Copying Image - L00385770_5.png in Fotos_Augmented/ArroboMercy
# Copying Image - L00385770_6.png in Fotos_Augmented/ArroboMercy
# Copying Image - L00385770_7.png in Fotos_Augmented/ArroboMercy
# Copying Image - L00385770_8.png in Fotos_Augmented/ArroboMercy
# Copying Image - L00392978_1.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_10.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_11.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_12.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_13.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_14.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_2.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_3.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_4.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_5.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_6.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_7.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_8.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00392978_9.jpg in Fotos_Augmented/BarraganSteven
# Copying Image - L00376416_1.jpg in Fotos_Augmented/CevallosJoan
# Copying Image - L00376416_2.jpg in Fotos_Augmented/CevallosJoan
# Copying Image - L00376416_3.jpg in Fotos_Augmented/CevallosJoan
# Copying Image - L00376416_4.jpg in Fotos_Augmented/CevallosJoan
# Copying Image - L00376416_5.jpg in Fotos_Augmented/CevallosJoan
# Copying Image - L00376416_6.jpg in Fotos_Augmented/CevallosJoan
# Copying Image - L00376416_7.jpg in Fotos_Augmented/CevallosJoan
# Copying Image - L00376416_8.jpg in Fotos_Augmented/CevallosJoan
# Copying Image - L00376416_9.jpg in Fotos_Augmented/CevallosJoan
# Copying Image - L000376481_1.jpg in Fotos_Augmented/EnriquezSelena
# Copying Image - L000376481_2.jpg in Fotos_Augmented/EnriquezSelena
# Copying Image - L000376481_3.jpg in Fotos_Augmented/EnriquezSelena
# Copying Image - L000376481_4.jpg in Fotos_Augmented/EnriquezSelena
# Copying Image - L000376481_5.jpg in Fotos_Augmented/EnriquezSelena
# Copying Image - L00392991_1.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00392991_10.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00392991_2.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00392991_3.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00392991_4.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00392991_5.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00392991_6.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00392991_7.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00392991_8.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00392991_9.jpeg in Fotos_Augmented/GenesisHeredia
# Copying Image - L00393010_1.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L00393010_10.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L00393010_2.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L00393010_3.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L00393010_4.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L00393010_5.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L00393010_6.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L00393010_7.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L00393010_8.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L00393010_9.jpg in Fotos_Augmented/GoyesAnthony
# Copying Image - L003392989_4.jpg in Fotos_Augmented/HectorCedenio
# Copying Image - L003392989_5.jpg in Fotos_Augmented/HectorCedenio
# Copying Image - L003392989_6.jpg in Fotos_Augmented/HectorCedenio
# Copying Image - L003392989_7.jpg in Fotos_Augmented/HectorCedenio
# Copying Image - L003392989_8.jpg in Fotos_Augmented/HectorCedenio
# Copying Image - L00392993_10.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_11.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_12.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_13.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_4.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_5.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_6.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_7.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_8.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_9.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_Centro.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_LD.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00392993_LI.jpg in Fotos_Augmented/Jhon Zambrano
# Copying Image - L00080128_1 Frente.png in Fotos_Augmented/Jordan Espinosa
# Copying Image - L00080128_2 Derecho.png in Fotos_Augmented/Jordan Espinosa
# Copying Image - L00080128_3 Izquierda.png in Fotos_Augmented/Jordan Espinosa
# Copying Image - L00080128_4.jpg in Fotos_Augmented/Jordan Espinosa
# Copying Image - L00080128_5.jpg in Fotos_Augmented/Jordan Espinosa
# Copying Image - L00080128_6.jpg in Fotos_Augmented/Jordan Espinosa
# Copying Image - L00080128_7.jpg in Fotos_Augmented/Jordan Espinosa
# Copying Image - L00080128_8.jpg in Fotos_Augmented/Jordan Espinosa
# Copying Image - L00379412_1.jpeg in Fotos_Augmented/Jorge Borrero
# Copying Image - L00379412_2.jpeg in Fotos_Augmented/Jorge Borrero
# Copying Image - L00379412_3.jpeg in Fotos_Augmented/Jorge Borrero
# Copying Image - IMG_20220817_160238.jpg in Fotos_Augmented/JoseRuiz
# Copying Image - IMG_20220817_160245.jpg in Fotos_Augmented/JoseRuiz
# Copying Image - IMG_20220817_160311.jpg in Fotos_Augmented/JoseRuiz
# Copying Image - IMG_20220817_160317.jpg in Fotos_Augmented/JoseRuiz
# Copying Image - IMG_20220817_160356.jpg in Fotos_Augmented/JoseRuiz
# Copying Image - L00380361_1.jpg in Fotos_Augmented/JoseRuiz
# Copying Image - L00380361_2.jpg in Fotos_Augmented/JoseRuiz
# Copying Image - L00380361_3.jpg in Fotos_Augmented/JoseRuiz
# Copying Image - L00393009_1.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - L00393009_10.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - L00393009_2.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - L00393009_3.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - L00393009_4.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - L00393009_5.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - L00393009_6.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - L00393009_7.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - L00393009_8.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - L00393009_9.jpeg in Fotos_Augmented/LucioCarlos
# Copying Image - 20220803_110911.jpg in Fotos_Augmented/MasacheFernando
# Copying Image - 20220803_110958(1).jpg in Fotos_Augmented/MasacheFernando
# Copying Image - 20220803_110958(2).jpg in Fotos_Augmented/MasacheFernando
# Copying Image - 20220803_110958(3).jpg in Fotos_Augmented/MasacheFernando
# Copying Image - 20220803_110958.jpg in Fotos_Augmented/MasacheFernando
# Copying Image - 20220803_111006.jpg in Fotos_Augmented/MasacheFernando
# Copying Image - IDPhoto_20220817_132123.jpg in Fotos_Augmented/MasacheFernando
# Copying Image - IDPhoto_20220817_132216.jpg in Fotos_Augmented/MasacheFernando
# Copying Image - IDPhoto_20220817_132420.jpg in Fotos_Augmented/MasacheFernando
# Copying Image - IDPhoto_20220817_132542.jpg in Fotos_Augmented/MasacheFernando
# Copying Image - L00392999_1.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_10.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_11.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_2.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_3.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_4.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_5.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_6.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_7.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_8.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00392999_9.jpg in Fotos_Augmented/MelanyLopez
# Copying Image - L00073392_1.jpg in Fotos_Augmented/MosqueraLucy
# Copying Image - L00073392_2.jpg in Fotos_Augmented/MosqueraLucy
# Copying Image - L00073392_3.jpg in Fotos_Augmented/MosqueraLucy
# Copying Image - L00073392_4.jpg in Fotos_Augmented/MosqueraLucy
# Copying Image - L00073392_5.jpg in Fotos_Augmented/MosqueraLucy
# Copying Image - L00073392_6.jpg in Fotos_Augmented/MosqueraLucy
# Copying Image - L00073392_7.jpg in Fotos_Augmented/MosqueraLucy
# Copying Image - L00073392_8.jpg in Fotos_Augmented/MosqueraLucy
# Copying Image - L00073392_9.jpg in Fotos_Augmented/MosqueraLucy
# Copying Image - L00380424_1.jpg in Fotos_Augmented/Nataly Acosta
# Copying Image - L00380424_2.jpg in Fotos_Augmented/Nataly Acosta
# Copying Image - L00380424_3.jpg in Fotos_Augmented/Nataly Acosta
# Copying Image - L00380424_4.jpg in Fotos_Augmented/Nataly Acosta
# Copying Image - L00380424_5.jpg in Fotos_Augmented/Nataly Acosta
# Copying Image - L00380424_6.jpg in Fotos_Augmented/Nataly Acosta
# Copying Image - L00380424_7.jpg in Fotos_Augmented/Nataly Acosta
# Copying Image - L00380424_8.jpg in Fotos_Augmented/Nataly Acosta
# Copying Image - L00393001_1.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_10.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_11.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_12.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_13.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_2.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_3.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_4.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_5.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_6.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_7.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_8.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00393001_9.jpg in Fotos_Augmented/OlallaLuis
# Copying Image - L00392984_1.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00392984_10.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00392984_2.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00392984_3.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00392984_4.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00392984_5.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00392984_6.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00392984_7.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00392984_8.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00392984_9.jpg in Fotos_Augmented/ParragaMariaJose
# Copying Image - L00080134_1.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080134_10.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080134_2.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080134_3.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080134_4.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080134_5.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080134_6.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080134_7.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080134_8.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080134_9.jpg in Fotos_Augmented/PauteKevin
# Copying Image - L00080957_1.jpg in Fotos_Augmented/Raymond Davila
# Copying Image - L00080957_2.jpg in Fotos_Augmented/Raymond Davila
# Copying Image - L00080957_3.jpg in Fotos_Augmented/Raymond Davila
# Copying Image - L00080957_4.jpg in Fotos_Augmented/Raymond Davila
# Copying Image - L00080957_5.jpg in Fotos_Augmented/Raymond Davila
# Copying Image - L00080957_6.jpg in Fotos_Augmented/Raymond Davila
# Copying Image - L00080957_7.jpg in Fotos_Augmented/Raymond Davila
# Copying Image - L00080957_8.jpg in Fotos_Augmented/Raymond Davila
# Copying Image - L00080957_9.jpg in Fotos_Augmented/Raymond Davila
# Copying Image - L00376689_1.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_10.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_11.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_2.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_3.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_4.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_5.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_6.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_7.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_8.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00376689_9.jpg in Fotos_Augmented/RivasSelena
# Copying Image - L00380416_1.png in Fotos_Augmented/SalazarJohana
# Copying Image - L00380416_2.png in Fotos_Augmented/SalazarJohana
# Copying Image - L00380416_3.png in Fotos_Augmented/SalazarJohana
# Copying Image - L00380416_4.png in Fotos_Augmented/SalazarJohana
# Copying Image - L00380416_5.png in Fotos_Augmented/SalazarJohana
# Copying Image - L00392980_1.jpg in Fotos_Augmented/Solano Wilmer
# Copying Image - L00392980_2.jpg in Fotos_Augmented/Solano Wilmer
# Copying Image - L00392980_3.jpg in Fotos_Augmented/Solano Wilmer
# Copying Image - L00392980_4.jpg in Fotos_Augmented/Solano Wilmer
# Copying Image - L00392980_5.jpg in Fotos_Augmented/Solano Wilmer
# Copying Image - L00080131_1.jpg in Fotos_Augmented/SolorzanoBryan
# Copying Image - L00080131_2.jpg in Fotos_Augmented/SolorzanoBryan
# Copying Image - L00080131_3.jpg in Fotos_Augmented/SolorzanoBryan
# Copying Image - L00080131_4.jpg in Fotos_Augmented/SolorzanoBryan
# Copying Image - L00080131_5.jpg in Fotos_Augmented/SolorzanoBryan
# Copying Image - L00080131_6.jpg in Fotos_Augmented/SolorzanoBryan
# Copying Image - L00080131_7.jpg in Fotos_Augmented/SolorzanoBryan
# Copying Image - L00080131_8.jpg in Fotos_Augmented/SolorzanoBryan
# Copying Image - L00080131_9.jpg in Fotos_Augmented/SolorzanoBryan
# Copying Image - L00393007_1.jpeg in Fotos_Augmented/VinicioBorja
# Copying Image - L00393007_10.jpeg in Fotos_Augmented/VinicioBorja
# Copying Image - L00393007_2.jpeg in Fotos_Augmented/VinicioBorja
# Copying Image - L00393007_3.jpeg in Fotos_Augmented/VinicioBorja
# Copying Image - L00393007_4.jpeg in Fotos_Augmented/VinicioBorja
# Copying Image - L00393007_5.jpeg in Fotos_Augmented/VinicioBorja
# Copying Image - L00393007_6.jpeg in Fotos_Augmented/VinicioBorja
# Copying Image - L00393007_7.jpeg in Fotos_Augmented/VinicioBorja
# Copying Image - L00393007_8.jpeg in Fotos_Augmented/VinicioBorja
# Copying Image - L00393007_9.jpeg in Fotos_Augmented/VinicioBorja

# %% [markdown]
# ## Impresión del dataset

# %%
image = []
#Creamos un bucle que se ejecutara hasta que se hayan leido todas las clases
for class_name in nombres:
    # Creamos una ruta especifica con el nombre de la clase
    cur_path = folder+"/" + class_name
    # Obtenemos los elementos de la ruta indicada
    elements = os.listdir(cur_path)
    #Definimos un bucle que lea todos los elementos
    for element in elements:
        image.append(io.imread(folder + "/" + class_name +'/'+ element)/255.0) # imread lee las imagenes con los pixeles codificados como enteros 
        # en el rango 0-255. Por eso la convertimos a flotante y en el rango 0-1
        
for i in range(9):
    print("- Dimensiones de la imagen:")
    ran = random.randint(0, len(image) - 1)
    print(image[ran].shape)
    plt.imshow(image[ran],vmin=0,vmax=1)
    plt.show()
# Out:
# - Dimensiones de la imagen:
# (189, 189, 3)
# - Dimensiones de la imagen:
# (192, 192, 3)
# - Dimensiones de la imagen:
# (192, 192, 4)
# - Dimensiones de la imagen:
# (189, 189, 3)
# - Dimensiones de la imagen:
# (302, 302, 3)
# - Dimensiones de la imagen:
# (192, 192, 3)
# - Dimensiones de la imagen:
# (192, 192, 3)
# - Dimensiones de la imagen:
# (192, 192, 3)
# - Dimensiones de la imagen:
# (192, 192, 3)

# %% [markdown]
# ## Data Aumentation

# %%
# Definimos las caracteristicas de las imagenes
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.4,
        horizontal_flip=True,
        fill_mode='nearest')

# %% [markdown]
# ## Clase Barragan Steven

# %%
#Definimos la ruta
os.chdir(r"C:\IAU3/Fotos_Augmented/BarraganSteven/")

#Definimos un bucle que recorra la ruta
for path in os.listdir():
    # Cargamos la imagen
    img = load_img(f"{path}")
    
    # Creamos un array Numpy con forma(3, 150, 150)
    x = img_to_array(img)
    
    #Reescalamos la imagen
    x = cv2.resize(x, (192, 192))
    # Realisamos un remodelado de las imagen
    x = x.reshape((1,) + x.shape)
    # Inicializamos la variable i
    i = 0
    # Deginimos un bucle que almacenara las nuevas fotos creadas
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Barragan_Steven', 
            save_format='jpg'):
        # Aumentamos el contador
        i += 1
        # Condición de detención del bucle
        if i == 10:
            #Fin del bucle
            break

# %% [markdown]
# ## Clase Cevallos Joan

# %%
#Definimos la ruta
os.chdir(r"C:\IAU3/Fotos_Augmented/CevallosJoan/")

#Definimos un bucle que recorra la ruta
for path in os.listdir():
    # Cargamos la imagen
    img = load_img(f"{path}")
    # Creamos un array Numpy con forma(3, 150, 150)
    x = img_to_array(img)
    #Reescalamos la imagen
    x = cv2.resize(x, (192, 192))
    # Realisamos un remodelado de las imagen
    x = x.reshape((1,) + x.shape)
    # Inicializamos la variable i
    i = 0
    # Deginimos un bucle que almacenara las nuevas fotos creadas
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Cevallos_Joan', 
            save_format='jpg'):
        # Aumentamos el contador
        i += 1
        # Condición de detención del bucle
        if i == 10:
            #Fin del bucle
            break

# %% [markdown]
# ## Clase Leonardo Borja

# %%
#Definimos la ruta
os.chdir(r"C:\IAU3/Fotos_Augmented/BorjaLeonardo/")

#Definimos un bucle que recorra la ruta
for path in os.listdir():
    # Cargamos la imagen
    img = load_img(f"{path}")
    # Creamos un array Numpy con forma(3, 150, 150)
    x = img_to_array(img)
    #Reescalamos la imagen
    x = cv2.resize(x, (192, 192))
    # Realisamos un remodelado de las imagen
    x = x.reshape((1,) + x.shape)
    # Inicializamos la variable i
    i = 0
    # Deginimos un bucle que almacenara las nuevas fotos creadas
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Leonardo_Borja', 
            save_format='jpg'):
        # Aumentamos el contador
        i += 1
        # Condición de detención del bucle
        if i == 10:
            #Fin del bucle
            break

# %% [markdown]
# ## Clase Melany López

# %%
#Definimos la ruta
os.chdir(r"C:\IAU3/Fotos_Augmented/LopezMelany/")

#Definimos un bucle que recorra la ruta
for path in os.listdir():
    # Cargamos la imagen
    img = load_img(f"{path}")
    # Creamos un array Numpy con forma(3, 150, 150)
    x = img_to_array(img)
    #Reescalamos la imagen
    x = cv2.resize(x, (192, 192))
    # Realisamos un remodelado de las imagen
    x = x.reshape((1,) + x.shape)
    # Inicializamos la variable i
    i = 0
    # Deginimos un bucle que almacenara las nuevas fotos creadas
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Melany_Lopez', 
            save_format='jpg'):
        # Aumentamos el contador
        i += 1
        # Condición de detención del bucle
        if i == 10:
            #Fin del bucle
            break

# %% [markdown]
# ## Clase Rivas Selena

# %%
#Definimos la ruta
os.chdir(r"C:\IAU3/Fotos_Augmented/RivasSelena/")
#Definimos un bucle que recorra la ruta
for path in os.listdir():
    # Cargamos la imagen
    img = load_img(f"{path}")
    # Creamos un array Numpy con forma(3, 150, 150)
    x = img_to_array(img)
    #Reescalamos la imagen
    x = cv2.resize(x, (192, 192))
    # Realisamos un remodelado de las imagen
    x = x.reshape((1,) + x.shape)
    # Inicializamos la variable i
    i = 0
    # Deginimos un bucle que almacenara las nuevas fotos creadas
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Rivas_Selena', 
            save_format='jpg'):
        # Aumentamos el contador
        i += 1
        # Condición de detención del bucle
        if i == 10:
            #Fin del bucle
            break

# %% [markdown]
# # Augmentation general

# %%
#Creamos un bucle que se ejecutara hasta que se hayan leido todas las clases
for class_name in nombres:
    # Creamos una ruta especifica con el nombre de la clase
    cur_path = "C:\IAU3/Fotos_Augmented/" + class_name
    # Obtenemos los elementos de la ruta indicada
    elements = os.listdir(cur_path)
    #Definimos un bucle que lea todos los elementos
    for element in elements:
        # Cargamos la imagen
        img = load_img(cur_path+"/"+element)
        # Creamos un array Numpy con forma(3, 150, 150)
        x = img_to_array(img)
        #Reescalamos la imagen
        x = cv2.resize(x, (192, 192))
        # Realisamos un remodelado de las imagen
        x = x.reshape((1,) + x.shape)
        # Inicializamos la variable i
        i = 0
        # Deginimos un bucle que almacenara las nuevas fotos creadas
        for batch in datagen.flow(x, batch_size=1,
                save_to_dir="C:\IAU3/Fotos_Augmented/"+class_name, 
                save_prefix= class_name, 
                save_format='jpg'):
            # Aumentamos el contador
            i += 1
            # Condición de detención del bucle
            if i == 10:
                #Fin del bucle
                break

# %% [markdown]
# ## Redimención de las fotos

# %%
# Definimos las caracteristicas de las imagenes
datagenResize = ImageDataGenerator(
        rotation_range=0,
        width_shift_range=0,
        height_shift_range=0,
        rescale=1./255,
        shear_range=0,
        zoom_range=0,
        horizontal_flip=False,
        )

# %%
#Creamos un bucle que se ejecutara hasta que se hayan leido todas las clases
for class_name in nombres:
    # Creamos una ruta especifica con el nombre de la clase
    cur_path = "C:\IAU3/Fotos_Augmented/" + class_name
    # Obtenemos los elementos de la ruta indicada
    elements = os.listdir(cur_path)
    #Definimos un bucle que lea todos los elementos
    for element in elements:
        # Cargamos la imagen
        img = load_img(cur_path+"/"+element)
        # Creamos un array Numpy con forma(3, 150, 150)
        x = img_to_array(img)
        #Reescalamos la imagen
        x = cv2.resize(x, (192, 192))
        # Realisamos un remodelado de las imagen
        x = x.reshape((1,) + x.shape)
        # Inicializamos la variable i
        i = 0
        # Deginimos un bucle que almacenara las nuevas fotos creadas
        for batch in datagenResize.flow(x, batch_size=1,
                save_to_dir="C:\IAU3/Fotos_Resize/"+class_name, 
                save_prefix= class_name, 
                save_format='jpg'):
            # Aumentamos el contador
            i += 1
            # Condición de detención del bucle
            if i == 1:
                #Fin del bucle
                break

# %% [markdown]
# ## Filtro NLM para eliminación de ruido de imágenes

# %%
# Establecemos la ruta de las imagenes
os.chdir(r"C:\IAU3")
# Asignamos la ruta de las fotos
images_path = "./Fotos_Resize/"
# Almacenamos los nombres de la clases
class_names = os.listdir(images_path)
# Ordenamos la lista
class_names.sort()
# Mostramos las clases
print(class_names)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'HectorCedenio', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MasacheFernando', 'MelanyLopez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMariaJose', 'PauteKevin', 'Raymond Davila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']

# %%
# Definimos un bucle que recorra todas las clases
for class_name in class_names:
    # Obtenemos la ruta de la clase
    cur_path = images_path + "/" + class_name
    # Asignamos la etiqueta de la clase
    cur_label = class_name
    # Inicializamos el contador
    i = 1

    # Definimos un bucle for que recorra todos los elementos
    for file in glob.glob(cur_path + "/*"):
        #Imprimimos un mensaje con la acción ejecutada
        print("Processing Image - {} in {}".format(i, cur_label))
        # Leemos la ruta de la imagen
        image = cv2.imread(file)
        # Eliminamos el ruido de las imagenes
        dst = cv2.fastNlMeansDenoisingColored(image,None,10,10,7,21)
        # Obtenemos el esquema de color
        b,g,r = cv2.split(dst)
        # Establecemos el esquema de color
        rgb_dst = cv2.merge([r,g,b])
        # Guardamos la imagen
        save_path = './Fotos_SinRuido/'+ cur_label
        cv2.imwrite(os.path.join(save_path , cur_label + '_' + str(i) + '.jpg'),
                    cv2.cvtColor(rgb_dst,cv2.COLOR_RGB2BGR))
        

        # Mostramos el ciclo
        i += 1
# Out:
# Processing Image - 1 in Ariel Chabla
# Processing Image - 2 in Ariel Chabla
# Processing Image - 3 in Ariel Chabla
# Processing Image - 4 in Ariel Chabla
# Processing Image - 5 in Ariel Chabla
# Processing Image - 6 in Ariel Chabla
# Processing Image - 7 in Ariel Chabla
# Processing Image - 8 in Ariel Chabla
# Processing Image - 9 in Ariel Chabla
# Processing Image - 10 in Ariel Chabla
# Processing Image - 11 in Ariel Chabla
# Processing Image - 12 in Ariel Chabla
# Processing Image - 13 in Ariel Chabla
# Processing Image - 14 in Ariel Chabla
# Processing Image - 15 in Ariel Chabla
# Processing Image - 16 in Ariel Chabla
# Processing Image - 17 in Ariel Chabla
# Processing Image - 18 in Ariel Chabla
# Processing Image - 19 in Ariel Chabla
# Processing Image - 20 in Ariel Chabla
# Processing Image - 21 in Ariel Chabla
# Processing Image - 22 in Ariel Chabla
# Processing Image - 23 in Ariel Chabla
# Processing Image - 24 in Ariel Chabla
# Processing Image - 25 in Ariel Chabla
# Processing Image - 26 in Ariel Chabla
# Processing Image - 27 in Ariel Chabla
# Processing Image - 28 in Ariel Chabla
# Processing Image - 29 in Ariel Chabla
# Processing Image - 30 in Ariel Chabla
# Processing Image - 31 in Ariel Chabla
# Processing Image - 32 in Ariel Chabla
# Processing Image - 33 in Ariel Chabla
# Processing Image - 34 in Ariel Chabla
# Processing Image - 35 in Ariel Chabla
# Processing Image - 36 in Ariel Chabla
# Processing Image - 37 in Ariel Chabla
# Processing Image - 38 in Ariel Chabla
# Processing Image - 39 in Ariel Chabla
# Processing Image - 40 in Ariel Chabla
# Processing Image - 41 in Ariel Chabla
# Processing Image - 42 in Ariel Chabla
# Processing Image - 43 in Ariel Chabla
# Processing Image - 44 in Ariel Chabla
# Processing Image - 45 in Ariel Chabla
# Processing Image - 46 in Ariel Chabla
# Processing Image - 47 in Ariel Chabla
# Processing Image - 48 in Ariel Chabla
# Processing Image - 49 in Ariel Chabla
# Processing Image - 50 in Ariel Chabla
# Processing Image - 51 in Ariel Chabla
# Processing Image - 52 in Ariel Chabla
# Processing Image - 53 in Ariel Chabla
# Processing Image - 54 in Ariel Chabla
# Processing Image - 55 in Ariel Chabla
# Processing Image - 56 in Ariel Chabla
# Processing Image - 57 in Ariel Chabla
# Processing Image - 58 in Ariel Chabla
# Processing Image - 59 in Ariel Chabla
# Processing Image - 60 in Ariel Chabla
# Processing Image - 61 in Ariel Chabla
# Processing Image - 62 in Ariel Chabla
# Processing Image - 63 in Ariel Chabla
# Processing Image - 64 in Ariel Chabla
# Processing Image - 65 in Ariel Chabla
# Processing Image - 66 in Ariel Chabla
# Processing Image - 67 in Ariel Chabla
# Processing Image - 68 in Ariel Chabla
# Processing Image - 69 in Ariel Chabla
# Processing Image - 70 in Ariel Chabla
# Processing Image - 71 in Ariel Chabla
# Processing Image - 72 in Ariel Chabla
# Processing Image - 73 in Ariel Chabla
# Processing Image - 74 in Ariel Chabla
# Processing Image - 75 in Ariel Chabla
# Processing Image - 76 in Ariel Chabla
# Processing Image - 77 in Ariel Chabla
# Processing Image - 78 in Ariel Chabla
# Processing Image - 79 in Ariel Chabla
# Processing Image - 80 in Ariel Chabla
# Processing Image - 81 in Ariel Chabla
# Processing Image - 82 in Ariel Chabla
# Processing Image - 83 in Ariel Chabla
# Processing Image - 84 in Ariel Chabla
# Processing Image - 85 in Ariel Chabla
# Processing Image - 86 in Ariel Chabla
# Processing Image - 87 in Ariel Chabla
# Processing Image - 88 in Ariel Chabla
# Processing Image - 1 in ArroboMercy
# Processing Image - 2 in ArroboMercy
# Processing Image - 3 in ArroboMercy
# Processing Image - 4 in ArroboMercy
# Processing Image - 5 in ArroboMercy
# Processing Image - 6 in ArroboMercy
# Processing Image - 7 in ArroboMercy
# Processing Image - 8 in ArroboMercy
# Processing Image - 9 in ArroboMercy
# Processing Image - 10 in ArroboMercy
# Processing Image - 11 in ArroboMercy
# Processing Image - 12 in ArroboMercy
# Processing Image - 13 in ArroboMercy
# Processing Image - 14 in ArroboMercy
# Processing Image - 15 in ArroboMercy
# Processing Image - 16 in ArroboMercy
# Processing Image - 17 in ArroboMercy
# Processing Image - 18 in ArroboMercy
# Processing Image - 19 in ArroboMercy
# Processing Image - 20 in ArroboMercy
# Processing Image - 21 in ArroboMercy
# Processing Image - 22 in ArroboMercy
# Processing Image - 23 in ArroboMercy
# Processing Image - 24 in ArroboMercy
# Processing Image - 25 in ArroboMercy
# Processing Image - 26 in ArroboMercy
# Processing Image - 27 in ArroboMercy
# Processing Image - 28 in ArroboMercy
# Processing Image - 29 in ArroboMercy
# Processing Image - 30 in ArroboMercy
# Processing Image - 31 in ArroboMercy
# Processing Image - 32 in ArroboMercy
# Processing Image - 33 in ArroboMercy
# Processing Image - 34 in ArroboMercy
# Processing Image - 35 in ArroboMercy
# Processing Image - 36 in ArroboMercy
# Processing Image - 37 in ArroboMercy
# Processing Image - 38 in ArroboMercy
# Processing Image - 39 in ArroboMercy
# Processing Image - 40 in ArroboMercy
# Processing Image - 41 in ArroboMercy
# Processing Image - 42 in ArroboMercy
# Processing Image - 43 in ArroboMercy
# Processing Image - 44 in ArroboMercy
# Processing Image - 45 in ArroboMercy
# Processing Image - 46 in ArroboMercy
# Processing Image - 47 in ArroboMercy
# Processing Image - 48 in ArroboMercy
# Processing Image - 49 in ArroboMercy
# Processing Image - 50 in ArroboMercy
# Processing Image - 51 in ArroboMercy
# Processing Image - 52 in ArroboMercy
# Processing Image - 53 in ArroboMercy
# Processing Image - 54 in ArroboMercy
# Processing Image - 55 in ArroboMercy
# Processing Image - 56 in ArroboMercy
# Processing Image - 57 in ArroboMercy
# Processing Image - 58 in ArroboMercy
# Processing Image - 59 in ArroboMercy
# Processing Image - 60 in ArroboMercy
# Processing Image - 61 in ArroboMercy
# Processing Image - 62 in ArroboMercy
# Processing Image - 63 in ArroboMercy
# Processing Image - 64 in ArroboMercy
# Processing Image - 65 in ArroboMercy
# Processing Image - 66 in ArroboMercy
# Processing Image - 67 in ArroboMercy
# Processing Image - 68 in ArroboMercy
# Processing Image - 69 in ArroboMercy
# Processing Image - 70 in ArroboMercy
# Processing Image - 71 in ArroboMercy
# Processing Image - 72 in ArroboMercy
# Processing Image - 73 in ArroboMercy
# Processing Image - 74 in ArroboMercy
# Processing Image - 75 in ArroboMercy
# Processing Image - 76 in ArroboMercy
# Processing Image - 77 in ArroboMercy
# Processing Image - 78 in ArroboMercy
# Processing Image - 79 in ArroboMercy
# Processing Image - 80 in ArroboMercy
# Processing Image - 81 in ArroboMercy
# Processing Image - 82 in ArroboMercy
# Processing Image - 83 in ArroboMercy
# Processing Image - 84 in ArroboMercy
# Processing Image - 85 in ArroboMercy
# Processing Image - 86 in ArroboMercy
# Processing Image - 87 in ArroboMercy
# Processing Image - 1 in BarraganSteven
# Processing Image - 2 in BarraganSteven
# Processing Image - 3 in BarraganSteven
# Processing Image - 4 in BarraganSteven
# Processing Image - 5 in BarraganSteven
# Processing Image - 6 in BarraganSteven
# Processing Image - 7 in BarraganSteven
# Processing Image - 8 in BarraganSteven
# Processing Image - 9 in BarraganSteven
# Processing Image - 10 in BarraganSteven
# Processing Image - 11 in BarraganSteven
# Processing Image - 12 in BarraganSteven
# Processing Image - 13 in BarraganSteven
# Processing Image - 14 in BarraganSteven
# Processing Image - 15 in BarraganSteven
# Processing Image - 16 in BarraganSteven
# Processing Image - 17 in BarraganSteven
# Processing Image - 18 in BarraganSteven
# Processing Image - 19 in BarraganSteven
# Processing Image - 20 in BarraganSteven
# Processing Image - 21 in BarraganSteven
# Processing Image - 22 in BarraganSteven
# Processing Image - 23 in BarraganSteven
# Processing Image - 24 in BarraganSteven
# Processing Image - 25 in BarraganSteven
# Processing Image - 26 in BarraganSteven
# Processing Image - 27 in BarraganSteven
# Processing Image - 28 in BarraganSteven
# Processing Image - 29 in BarraganSteven
# Processing Image - 30 in BarraganSteven
# Processing Image - 31 in BarraganSteven
# Processing Image - 32 in BarraganSteven
# Processing Image - 33 in BarraganSteven
# Processing Image - 34 in BarraganSteven
# Processing Image - 35 in BarraganSteven
# Processing Image - 36 in BarraganSteven
# Processing Image - 37 in BarraganSteven
# Processing Image - 38 in BarraganSteven
# Processing Image - 39 in BarraganSteven
# Processing Image - 40 in BarraganSteven
# Processing Image - 41 in BarraganSteven
# Processing Image - 42 in BarraganSteven
# Processing Image - 43 in BarraganSteven
# Processing Image - 44 in BarraganSteven
# Processing Image - 45 in BarraganSteven
# Processing Image - 46 in BarraganSteven
# Processing Image - 47 in BarraganSteven
# Processing Image - 48 in BarraganSteven
# Processing Image - 49 in BarraganSteven
# Processing Image - 50 in BarraganSteven
# Processing Image - 51 in BarraganSteven
# Processing Image - 52 in BarraganSteven
# Processing Image - 53 in BarraganSteven
# Processing Image - 54 in BarraganSteven
# Processing Image - 55 in BarraganSteven
# Processing Image - 56 in BarraganSteven
# Processing Image - 57 in BarraganSteven
# Processing Image - 58 in BarraganSteven
# Processing Image - 59 in BarraganSteven
# Processing Image - 60 in BarraganSteven
# Processing Image - 61 in BarraganSteven
# Processing Image - 62 in BarraganSteven
# Processing Image - 63 in BarraganSteven
# Processing Image - 64 in BarraganSteven
# Processing Image - 65 in BarraganSteven
# Processing Image - 66 in BarraganSteven
# Processing Image - 67 in BarraganSteven
# Processing Image - 68 in BarraganSteven
# Processing Image - 69 in BarraganSteven
# Processing Image - 70 in BarraganSteven
# Processing Image - 71 in BarraganSteven
# Processing Image - 72 in BarraganSteven
# Processing Image - 73 in BarraganSteven
# Processing Image - 74 in BarraganSteven
# Processing Image - 75 in BarraganSteven
# Processing Image - 76 in BarraganSteven
# Processing Image - 77 in BarraganSteven
# Processing Image - 78 in BarraganSteven
# Processing Image - 79 in BarraganSteven
# Processing Image - 80 in BarraganSteven
# Processing Image - 81 in BarraganSteven
# Processing Image - 82 in BarraganSteven
# Processing Image - 83 in BarraganSteven
# Processing Image - 84 in BarraganSteven
# Processing Image - 85 in BarraganSteven
# Processing Image - 86 in BarraganSteven
# Processing Image - 87 in BarraganSteven
# Processing Image - 88 in BarraganSteven
# Processing Image - 89 in BarraganSteven
# Processing Image - 90 in BarraganSteven
# Processing Image - 91 in BarraganSteven
# Processing Image - 92 in BarraganSteven
# Processing Image - 93 in BarraganSteven
# Processing Image - 94 in BarraganSteven
# Processing Image - 95 in BarraganSteven
# Processing Image - 96 in BarraganSteven
# Processing Image - 97 in BarraganSteven
# Processing Image - 98 in BarraganSteven
# Processing Image - 99 in BarraganSteven
# Processing Image - 100 in BarraganSteven
# Processing Image - 101 in BarraganSteven
# Processing Image - 102 in BarraganSteven
# Processing Image - 103 in BarraganSteven
# Processing Image - 104 in BarraganSteven
# Processing Image - 105 in BarraganSteven
# Processing Image - 106 in BarraganSteven
# Processing Image - 107 in BarraganSteven
# Processing Image - 108 in BarraganSteven
# Processing Image - 109 in BarraganSteven
# Processing Image - 110 in BarraganSteven
# Processing Image - 111 in BarraganSteven
# Processing Image - 112 in BarraganSteven
# Processing Image - 113 in BarraganSteven
# Processing Image - 114 in BarraganSteven
# Processing Image - 115 in BarraganSteven
# Processing Image - 116 in BarraganSteven
# Processing Image - 117 in BarraganSteven
# Processing Image - 118 in BarraganSteven
# Processing Image - 119 in BarraganSteven
# Processing Image - 120 in BarraganSteven
# Processing Image - 121 in BarraganSteven
# Processing Image - 122 in BarraganSteven
# Processing Image - 123 in BarraganSteven
# Processing Image - 124 in BarraganSteven
# Processing Image - 125 in BarraganSteven
# Processing Image - 126 in BarraganSteven
# Processing Image - 127 in BarraganSteven
# Processing Image - 128 in BarraganSteven
# Processing Image - 129 in BarraganSteven
# Processing Image - 130 in BarraganSteven
# Processing Image - 131 in BarraganSteven
# Processing Image - 132 in BarraganSteven
# Processing Image - 133 in BarraganSteven
# Processing Image - 134 in BarraganSteven
# Processing Image - 135 in BarraganSteven
# Processing Image - 136 in BarraganSteven
# Processing Image - 137 in BarraganSteven
# Processing Image - 138 in BarraganSteven
# Processing Image - 139 in BarraganSteven
# Processing Image - 140 in BarraganSteven
# Processing Image - 141 in BarraganSteven
# Processing Image - 142 in BarraganSteven
# Processing Image - 143 in BarraganSteven
# Processing Image - 144 in BarraganSteven
# Processing Image - 145 in BarraganSteven
# Processing Image - 146 in BarraganSteven
# Processing Image - 147 in BarraganSteven
# Processing Image - 148 in BarraganSteven
# Processing Image - 149 in BarraganSteven
# Processing Image - 150 in BarraganSteven
# Processing Image - 151 in BarraganSteven
# Processing Image - 152 in BarraganSteven
# Processing Image - 153 in BarraganSteven
# Processing Image - 1 in CevallosJoan
# Processing Image - 2 in CevallosJoan
# Processing Image - 3 in CevallosJoan
# Processing Image - 4 in CevallosJoan
# Processing Image - 5 in CevallosJoan
# Processing Image - 6 in CevallosJoan
# Processing Image - 7 in CevallosJoan
# Processing Image - 8 in CevallosJoan
# Processing Image - 9 in CevallosJoan
# Processing Image - 10 in CevallosJoan
# Processing Image - 11 in CevallosJoan
# Processing Image - 12 in CevallosJoan
# Processing Image - 13 in CevallosJoan
# Processing Image - 14 in CevallosJoan
# Processing Image - 15 in CevallosJoan
# Processing Image - 16 in CevallosJoan
# Processing Image - 17 in CevallosJoan
# Processing Image - 18 in CevallosJoan
# Processing Image - 19 in CevallosJoan
# Processing Image - 20 in CevallosJoan
# Processing Image - 21 in CevallosJoan
# Processing Image - 22 in CevallosJoan
# Processing Image - 23 in CevallosJoan
# Processing Image - 24 in CevallosJoan
# Processing Image - 25 in CevallosJoan
# Processing Image - 26 in CevallosJoan
# Processing Image - 27 in CevallosJoan
# Processing Image - 28 in CevallosJoan
# Processing Image - 29 in CevallosJoan
# Processing Image - 30 in CevallosJoan
# Processing Image - 31 in CevallosJoan
# Processing Image - 32 in CevallosJoan
# Processing Image - 33 in CevallosJoan
# Processing Image - 34 in CevallosJoan
# Processing Image - 35 in CevallosJoan
# Processing Image - 36 in CevallosJoan
# Processing Image - 37 in CevallosJoan
# Processing Image - 38 in CevallosJoan
# Processing Image - 39 in CevallosJoan
# Processing Image - 40 in CevallosJoan
# Processing Image - 41 in CevallosJoan
# Processing Image - 42 in CevallosJoan
# Processing Image - 43 in CevallosJoan
# Processing Image - 44 in CevallosJoan
# Processing Image - 45 in CevallosJoan
# Processing Image - 46 in CevallosJoan
# Processing Image - 47 in CevallosJoan
# Processing Image - 48 in CevallosJoan
# Processing Image - 49 in CevallosJoan
# Processing Image - 50 in CevallosJoan
# Processing Image - 51 in CevallosJoan
# Processing Image - 52 in CevallosJoan
# Processing Image - 53 in CevallosJoan
# Processing Image - 54 in CevallosJoan
# Processing Image - 55 in CevallosJoan
# Processing Image - 56 in CevallosJoan
# Processing Image - 57 in CevallosJoan
# Processing Image - 58 in CevallosJoan
# Processing Image - 59 in CevallosJoan
# Processing Image - 60 in CevallosJoan
# Processing Image - 61 in CevallosJoan
# Processing Image - 62 in CevallosJoan
# Processing Image - 63 in CevallosJoan
# Processing Image - 64 in CevallosJoan
# Processing Image - 65 in CevallosJoan
# Processing Image - 66 in CevallosJoan
# Processing Image - 67 in CevallosJoan
# Processing Image - 68 in CevallosJoan
# Processing Image - 69 in CevallosJoan
# Processing Image - 70 in CevallosJoan
# Processing Image - 71 in CevallosJoan
# Processing Image - 72 in CevallosJoan
# Processing Image - 73 in CevallosJoan
# Processing Image - 74 in CevallosJoan
# Processing Image - 75 in CevallosJoan
# Processing Image - 76 in CevallosJoan
# Processing Image - 77 in CevallosJoan
# Processing Image - 78 in CevallosJoan
# Processing Image - 79 in CevallosJoan
# Processing Image - 80 in CevallosJoan
# Processing Image - 81 in CevallosJoan
# Processing Image - 82 in CevallosJoan
# Processing Image - 83 in CevallosJoan
# Processing Image - 84 in CevallosJoan
# Processing Image - 85 in CevallosJoan
# Processing Image - 86 in CevallosJoan
# Processing Image - 87 in CevallosJoan
# Processing Image - 88 in CevallosJoan
# Processing Image - 89 in CevallosJoan
# Processing Image - 90 in CevallosJoan
# Processing Image - 91 in CevallosJoan
# Processing Image - 92 in CevallosJoan
# Processing Image - 93 in CevallosJoan
# Processing Image - 94 in CevallosJoan
# Processing Image - 95 in CevallosJoan
# Processing Image - 96 in CevallosJoan
# Processing Image - 97 in CevallosJoan
# Processing Image - 98 in CevallosJoan
# Processing Image - 1 in EnriquezSelena
# Processing Image - 2 in EnriquezSelena
# Processing Image - 3 in EnriquezSelena
# Processing Image - 4 in EnriquezSelena
# Processing Image - 5 in EnriquezSelena
# Processing Image - 6 in EnriquezSelena
# Processing Image - 7 in EnriquezSelena
# Processing Image - 8 in EnriquezSelena
# Processing Image - 9 in EnriquezSelena
# Processing Image - 10 in EnriquezSelena
# Processing Image - 11 in EnriquezSelena
# Processing Image - 12 in EnriquezSelena
# Processing Image - 13 in EnriquezSelena
# Processing Image - 14 in EnriquezSelena
# Processing Image - 15 in EnriquezSelena
# Processing Image - 16 in EnriquezSelena
# Processing Image - 17 in EnriquezSelena
# Processing Image - 18 in EnriquezSelena
# Processing Image - 19 in EnriquezSelena
# Processing Image - 20 in EnriquezSelena
# Processing Image - 21 in EnriquezSelena
# Processing Image - 22 in EnriquezSelena
# Processing Image - 23 in EnriquezSelena
# Processing Image - 24 in EnriquezSelena
# Processing Image - 25 in EnriquezSelena
# Processing Image - 26 in EnriquezSelena
# Processing Image - 27 in EnriquezSelena
# Processing Image - 28 in EnriquezSelena
# Processing Image - 29 in EnriquezSelena
# Processing Image - 30 in EnriquezSelena
# Processing Image - 31 in EnriquezSelena
# Processing Image - 32 in EnriquezSelena
# Processing Image - 33 in EnriquezSelena
# Processing Image - 34 in EnriquezSelena
# Processing Image - 35 in EnriquezSelena
# Processing Image - 36 in EnriquezSelena
# Processing Image - 37 in EnriquezSelena
# Processing Image - 38 in EnriquezSelena
# Processing Image - 39 in EnriquezSelena
# Processing Image - 40 in EnriquezSelena
# Processing Image - 41 in EnriquezSelena
# Processing Image - 42 in EnriquezSelena
# Processing Image - 43 in EnriquezSelena
# Processing Image - 44 in EnriquezSelena
# Processing Image - 45 in EnriquezSelena
# Processing Image - 46 in EnriquezSelena
# Processing Image - 47 in EnriquezSelena
# Processing Image - 48 in EnriquezSelena
# Processing Image - 49 in EnriquezSelena
# Processing Image - 50 in EnriquezSelena
# Processing Image - 51 in EnriquezSelena
# Processing Image - 52 in EnriquezSelena
# Processing Image - 53 in EnriquezSelena
# Processing Image - 54 in EnriquezSelena
# Processing Image - 55 in EnriquezSelena
# Processing Image - 1 in GenesisHeredia
# Processing Image - 2 in GenesisHeredia
# Processing Image - 3 in GenesisHeredia
# Processing Image - 4 in GenesisHeredia
# Processing Image - 5 in GenesisHeredia
# Processing Image - 6 in GenesisHeredia
# Processing Image - 7 in GenesisHeredia
# Processing Image - 8 in GenesisHeredia
# Processing Image - 9 in GenesisHeredia
# Processing Image - 10 in GenesisHeredia
# Processing Image - 11 in GenesisHeredia
# Processing Image - 12 in GenesisHeredia
# Processing Image - 13 in GenesisHeredia
# Processing Image - 14 in GenesisHeredia
# Processing Image - 15 in GenesisHeredia
# Processing Image - 16 in GenesisHeredia
# Processing Image - 17 in GenesisHeredia
# Processing Image - 18 in GenesisHeredia
# Processing Image - 19 in GenesisHeredia
# Processing Image - 20 in GenesisHeredia
# Processing Image - 21 in GenesisHeredia
# Processing Image - 22 in GenesisHeredia
# Processing Image - 23 in GenesisHeredia
# Processing Image - 24 in GenesisHeredia
# Processing Image - 25 in GenesisHeredia
# Processing Image - 26 in GenesisHeredia
# Processing Image - 27 in GenesisHeredia
# Processing Image - 28 in GenesisHeredia
# Processing Image - 29 in GenesisHeredia
# Processing Image - 30 in GenesisHeredia
# Processing Image - 31 in GenesisHeredia
# Processing Image - 32 in GenesisHeredia
# Processing Image - 33 in GenesisHeredia
# Processing Image - 34 in GenesisHeredia
# Processing Image - 35 in GenesisHeredia
# Processing Image - 36 in GenesisHeredia
# Processing Image - 37 in GenesisHeredia
# Processing Image - 38 in GenesisHeredia
# Processing Image - 39 in GenesisHeredia
# Processing Image - 40 in GenesisHeredia
# Processing Image - 41 in GenesisHeredia
# Processing Image - 42 in GenesisHeredia
# Processing Image - 43 in GenesisHeredia
# Processing Image - 44 in GenesisHeredia
# Processing Image - 45 in GenesisHeredia
# Processing Image - 46 in GenesisHeredia
# Processing Image - 47 in GenesisHeredia
# Processing Image - 48 in GenesisHeredia
# Processing Image - 49 in GenesisHeredia
# Processing Image - 50 in GenesisHeredia
# Processing Image - 51 in GenesisHeredia
# Processing Image - 52 in GenesisHeredia
# Processing Image - 53 in GenesisHeredia
# Processing Image - 54 in GenesisHeredia
# Processing Image - 55 in GenesisHeredia
# Processing Image - 56 in GenesisHeredia
# Processing Image - 57 in GenesisHeredia
# Processing Image - 58 in GenesisHeredia
# Processing Image - 59 in GenesisHeredia
# Processing Image - 60 in GenesisHeredia
# Processing Image - 61 in GenesisHeredia
# Processing Image - 62 in GenesisHeredia
# Processing Image - 63 in GenesisHeredia
# Processing Image - 64 in GenesisHeredia
# Processing Image - 65 in GenesisHeredia
# Processing Image - 66 in GenesisHeredia
# Processing Image - 67 in GenesisHeredia
# Processing Image - 68 in GenesisHeredia
# Processing Image - 69 in GenesisHeredia
# Processing Image - 70 in GenesisHeredia
# Processing Image - 71 in GenesisHeredia
# Processing Image - 72 in GenesisHeredia
# Processing Image - 73 in GenesisHeredia
# Processing Image - 74 in GenesisHeredia
# Processing Image - 75 in GenesisHeredia
# Processing Image - 76 in GenesisHeredia
# Processing Image - 77 in GenesisHeredia
# Processing Image - 78 in GenesisHeredia
# Processing Image - 79 in GenesisHeredia
# Processing Image - 80 in GenesisHeredia
# Processing Image - 81 in GenesisHeredia
# Processing Image - 82 in GenesisHeredia
# Processing Image - 83 in GenesisHeredia
# Processing Image - 84 in GenesisHeredia
# Processing Image - 85 in GenesisHeredia
# Processing Image - 86 in GenesisHeredia
# Processing Image - 87 in GenesisHeredia
# Processing Image - 88 in GenesisHeredia
# Processing Image - 89 in GenesisHeredia
# Processing Image - 90 in GenesisHeredia
# Processing Image - 91 in GenesisHeredia
# Processing Image - 92 in GenesisHeredia
# Processing Image - 93 in GenesisHeredia
# Processing Image - 94 in GenesisHeredia
# Processing Image - 95 in GenesisHeredia
# Processing Image - 96 in GenesisHeredia
# Processing Image - 97 in GenesisHeredia
# Processing Image - 98 in GenesisHeredia
# Processing Image - 99 in GenesisHeredia
# Processing Image - 100 in GenesisHeredia
# Processing Image - 101 in GenesisHeredia
# Processing Image - 102 in GenesisHeredia
# Processing Image - 103 in GenesisHeredia
# Processing Image - 104 in GenesisHeredia
# Processing Image - 105 in GenesisHeredia
# Processing Image - 106 in GenesisHeredia
# Processing Image - 107 in GenesisHeredia
# Processing Image - 108 in GenesisHeredia
# Processing Image - 109 in GenesisHeredia
# Processing Image - 110 in GenesisHeredia
# Processing Image - 1 in GoyesAnthony
# Processing Image - 2 in GoyesAnthony
# Processing Image - 3 in GoyesAnthony
# Processing Image - 4 in GoyesAnthony
# Processing Image - 5 in GoyesAnthony
# Processing Image - 6 in GoyesAnthony
# Processing Image - 7 in GoyesAnthony
# Processing Image - 8 in GoyesAnthony
# Processing Image - 9 in GoyesAnthony
# Processing Image - 10 in GoyesAnthony
# Processing Image - 11 in GoyesAnthony
# Processing Image - 12 in GoyesAnthony
# Processing Image - 13 in GoyesAnthony
# Processing Image - 14 in GoyesAnthony
# Processing Image - 15 in GoyesAnthony
# Processing Image - 16 in GoyesAnthony
# Processing Image - 17 in GoyesAnthony
# Processing Image - 18 in GoyesAnthony
# Processing Image - 19 in GoyesAnthony
# Processing Image - 20 in GoyesAnthony
# Processing Image - 21 in GoyesAnthony
# Processing Image - 22 in GoyesAnthony
# Processing Image - 23 in GoyesAnthony
# Processing Image - 24 in GoyesAnthony
# Processing Image - 25 in GoyesAnthony
# Processing Image - 26 in GoyesAnthony
# Processing Image - 27 in GoyesAnthony
# Processing Image - 28 in GoyesAnthony
# Processing Image - 29 in GoyesAnthony
# Processing Image - 30 in GoyesAnthony
# Processing Image - 31 in GoyesAnthony
# Processing Image - 32 in GoyesAnthony
# Processing Image - 33 in GoyesAnthony
# Processing Image - 34 in GoyesAnthony
# Processing Image - 35 in GoyesAnthony
# Processing Image - 36 in GoyesAnthony
# Processing Image - 37 in GoyesAnthony
# Processing Image - 38 in GoyesAnthony
# Processing Image - 39 in GoyesAnthony
# Processing Image - 40 in GoyesAnthony
# Processing Image - 41 in GoyesAnthony
# Processing Image - 42 in GoyesAnthony
# Processing Image - 43 in GoyesAnthony
# Processing Image - 44 in GoyesAnthony
# Processing Image - 45 in GoyesAnthony
# Processing Image - 46 in GoyesAnthony
# Processing Image - 47 in GoyesAnthony
# Processing Image - 48 in GoyesAnthony
# Processing Image - 49 in GoyesAnthony
# Processing Image - 50 in GoyesAnthony
# Processing Image - 51 in GoyesAnthony
# Processing Image - 52 in GoyesAnthony
# Processing Image - 53 in GoyesAnthony
# Processing Image - 54 in GoyesAnthony
# Processing Image - 55 in GoyesAnthony
# Processing Image - 56 in GoyesAnthony
# Processing Image - 57 in GoyesAnthony
# Processing Image - 58 in GoyesAnthony
# Processing Image - 59 in GoyesAnthony
# Processing Image - 60 in GoyesAnthony
# Processing Image - 61 in GoyesAnthony
# Processing Image - 62 in GoyesAnthony
# Processing Image - 63 in GoyesAnthony
# Processing Image - 64 in GoyesAnthony
# Processing Image - 65 in GoyesAnthony
# Processing Image - 66 in GoyesAnthony
# Processing Image - 67 in GoyesAnthony
# Processing Image - 68 in GoyesAnthony
# Processing Image - 69 in GoyesAnthony
# Processing Image - 70 in GoyesAnthony
# Processing Image - 71 in GoyesAnthony
# Processing Image - 72 in GoyesAnthony
# Processing Image - 73 in GoyesAnthony
# Processing Image - 74 in GoyesAnthony
# Processing Image - 75 in GoyesAnthony
# Processing Image - 76 in GoyesAnthony
# Processing Image - 77 in GoyesAnthony
# Processing Image - 78 in GoyesAnthony
# Processing Image - 79 in GoyesAnthony
# Processing Image - 80 in GoyesAnthony
# Processing Image - 81 in GoyesAnthony
# Processing Image - 82 in GoyesAnthony
# Processing Image - 83 in GoyesAnthony
# Processing Image - 84 in GoyesAnthony
# Processing Image - 85 in GoyesAnthony
# Processing Image - 86 in GoyesAnthony
# Processing Image - 87 in GoyesAnthony
# Processing Image - 88 in GoyesAnthony
# Processing Image - 89 in GoyesAnthony
# Processing Image - 90 in GoyesAnthony
# Processing Image - 91 in GoyesAnthony
# Processing Image - 92 in GoyesAnthony
# Processing Image - 93 in GoyesAnthony
# Processing Image - 94 in GoyesAnthony
# Processing Image - 95 in GoyesAnthony
# Processing Image - 96 in GoyesAnthony
# Processing Image - 97 in GoyesAnthony
# Processing Image - 98 in GoyesAnthony
# Processing Image - 99 in GoyesAnthony
# Processing Image - 100 in GoyesAnthony
# Processing Image - 101 in GoyesAnthony
# Processing Image - 102 in GoyesAnthony
# Processing Image - 103 in GoyesAnthony
# Processing Image - 104 in GoyesAnthony
# Processing Image - 105 in GoyesAnthony
# Processing Image - 106 in GoyesAnthony
# Processing Image - 107 in GoyesAnthony
# Processing Image - 108 in GoyesAnthony
# Processing Image - 109 in GoyesAnthony
# Processing Image - 1 in HectorCedenio
# Processing Image - 2 in HectorCedenio
# Processing Image - 3 in HectorCedenio
# Processing Image - 4 in HectorCedenio
# Processing Image - 5 in HectorCedenio
# Processing Image - 6 in HectorCedenio
# Processing Image - 7 in HectorCedenio
# Processing Image - 8 in HectorCedenio
# Processing Image - 9 in HectorCedenio
# Processing Image - 10 in HectorCedenio
# Processing Image - 11 in HectorCedenio
# Processing Image - 12 in HectorCedenio
# Processing Image - 13 in HectorCedenio
# Processing Image - 14 in HectorCedenio
# Processing Image - 15 in HectorCedenio
# Processing Image - 16 in HectorCedenio
# Processing Image - 17 in HectorCedenio
# Processing Image - 18 in HectorCedenio
# Processing Image - 19 in HectorCedenio
# Processing Image - 20 in HectorCedenio
# Processing Image - 21 in HectorCedenio
# Processing Image - 22 in HectorCedenio
# Processing Image - 23 in HectorCedenio
# Processing Image - 24 in HectorCedenio
# Processing Image - 25 in HectorCedenio
# Processing Image - 26 in HectorCedenio
# Processing Image - 27 in HectorCedenio
# Processing Image - 28 in HectorCedenio
# Processing Image - 29 in HectorCedenio
# Processing Image - 30 in HectorCedenio
# Processing Image - 31 in HectorCedenio
# Processing Image - 32 in HectorCedenio
# Processing Image - 33 in HectorCedenio
# Processing Image - 34 in HectorCedenio
# Processing Image - 35 in HectorCedenio
# Processing Image - 36 in HectorCedenio
# Processing Image - 37 in HectorCedenio
# Processing Image - 38 in HectorCedenio
# Processing Image - 39 in HectorCedenio
# Processing Image - 40 in HectorCedenio
# Processing Image - 41 in HectorCedenio
# Processing Image - 42 in HectorCedenio
# Processing Image - 43 in HectorCedenio
# Processing Image - 44 in HectorCedenio
# Processing Image - 45 in HectorCedenio
# Processing Image - 46 in HectorCedenio
# Processing Image - 47 in HectorCedenio
# Processing Image - 48 in HectorCedenio
# Processing Image - 49 in HectorCedenio
# Processing Image - 50 in HectorCedenio
# Processing Image - 51 in HectorCedenio
# Processing Image - 52 in HectorCedenio
# Processing Image - 53 in HectorCedenio
# Processing Image - 54 in HectorCedenio
# Processing Image - 1 in Jhon Zambrano
# Processing Image - 2 in Jhon Zambrano
# Processing Image - 3 in Jhon Zambrano
# Processing Image - 4 in Jhon Zambrano
# Processing Image - 5 in Jhon Zambrano
# Processing Image - 6 in Jhon Zambrano
# Processing Image - 7 in Jhon Zambrano
# Processing Image - 8 in Jhon Zambrano
# Processing Image - 9 in Jhon Zambrano
# Processing Image - 10 in Jhon Zambrano
# Processing Image - 11 in Jhon Zambrano
# Processing Image - 12 in Jhon Zambrano
# Processing Image - 13 in Jhon Zambrano
# Processing Image - 14 in Jhon Zambrano
# Processing Image - 15 in Jhon Zambrano
# Processing Image - 16 in Jhon Zambrano
# Processing Image - 17 in Jhon Zambrano
# Processing Image - 18 in Jhon Zambrano
# Processing Image - 19 in Jhon Zambrano
# Processing Image - 20 in Jhon Zambrano
# Processing Image - 21 in Jhon Zambrano
# Processing Image - 22 in Jhon Zambrano
# Processing Image - 23 in Jhon Zambrano
# Processing Image - 24 in Jhon Zambrano
# Processing Image - 25 in Jhon Zambrano
# Processing Image - 26 in Jhon Zambrano
# Processing Image - 27 in Jhon Zambrano
# Processing Image - 28 in Jhon Zambrano
# Processing Image - 29 in Jhon Zambrano
# Processing Image - 30 in Jhon Zambrano
# Processing Image - 31 in Jhon Zambrano
# Processing Image - 32 in Jhon Zambrano
# Processing Image - 33 in Jhon Zambrano
# Processing Image - 34 in Jhon Zambrano
# Processing Image - 35 in Jhon Zambrano
# Processing Image - 36 in Jhon Zambrano
# Processing Image - 37 in Jhon Zambrano
# Processing Image - 38 in Jhon Zambrano
# Processing Image - 39 in Jhon Zambrano
# Processing Image - 40 in Jhon Zambrano
# Processing Image - 41 in Jhon Zambrano
# Processing Image - 42 in Jhon Zambrano
# Processing Image - 43 in Jhon Zambrano
# Processing Image - 44 in Jhon Zambrano
# Processing Image - 45 in Jhon Zambrano
# Processing Image - 46 in Jhon Zambrano
# Processing Image - 47 in Jhon Zambrano
# Processing Image - 48 in Jhon Zambrano
# Processing Image - 49 in Jhon Zambrano
# Processing Image - 50 in Jhon Zambrano
# Processing Image - 51 in Jhon Zambrano
# Processing Image - 52 in Jhon Zambrano
# Processing Image - 53 in Jhon Zambrano
# Processing Image - 54 in Jhon Zambrano
# Processing Image - 55 in Jhon Zambrano
# Processing Image - 56 in Jhon Zambrano
# Processing Image - 57 in Jhon Zambrano
# Processing Image - 58 in Jhon Zambrano
# Processing Image - 59 in Jhon Zambrano
# Processing Image - 60 in Jhon Zambrano
# Processing Image - 61 in Jhon Zambrano
# Processing Image - 62 in Jhon Zambrano
# Processing Image - 63 in Jhon Zambrano
# Processing Image - 64 in Jhon Zambrano
# Processing Image - 65 in Jhon Zambrano
# Processing Image - 66 in Jhon Zambrano
# Processing Image - 67 in Jhon Zambrano
# Processing Image - 68 in Jhon Zambrano
# Processing Image - 69 in Jhon Zambrano
# Processing Image - 70 in Jhon Zambrano
# Processing Image - 71 in Jhon Zambrano
# Processing Image - 72 in Jhon Zambrano
# Processing Image - 73 in Jhon Zambrano
# Processing Image - 74 in Jhon Zambrano
# Processing Image - 75 in Jhon Zambrano
# Processing Image - 76 in Jhon Zambrano
# Processing Image - 77 in Jhon Zambrano
# Processing Image - 78 in Jhon Zambrano
# Processing Image - 79 in Jhon Zambrano
# Processing Image - 80 in Jhon Zambrano
# Processing Image - 81 in Jhon Zambrano
# Processing Image - 82 in Jhon Zambrano
# Processing Image - 83 in Jhon Zambrano
# Processing Image - 84 in Jhon Zambrano
# Processing Image - 85 in Jhon Zambrano
# Processing Image - 86 in Jhon Zambrano
# Processing Image - 87 in Jhon Zambrano
# Processing Image - 88 in Jhon Zambrano
# Processing Image - 89 in Jhon Zambrano
# Processing Image - 90 in Jhon Zambrano
# Processing Image - 91 in Jhon Zambrano
# Processing Image - 92 in Jhon Zambrano
# Processing Image - 93 in Jhon Zambrano
# Processing Image - 94 in Jhon Zambrano
# Processing Image - 95 in Jhon Zambrano
# Processing Image - 96 in Jhon Zambrano
# Processing Image - 97 in Jhon Zambrano
# Processing Image - 98 in Jhon Zambrano
# Processing Image - 99 in Jhon Zambrano
# Processing Image - 100 in Jhon Zambrano
# Processing Image - 101 in Jhon Zambrano
# Processing Image - 102 in Jhon Zambrano
# Processing Image - 103 in Jhon Zambrano
# Processing Image - 104 in Jhon Zambrano
# Processing Image - 105 in Jhon Zambrano
# Processing Image - 106 in Jhon Zambrano
# Processing Image - 107 in Jhon Zambrano
# Processing Image - 108 in Jhon Zambrano
# Processing Image - 109 in Jhon Zambrano
# Processing Image - 110 in Jhon Zambrano
# Processing Image - 111 in Jhon Zambrano
# Processing Image - 112 in Jhon Zambrano
# Processing Image - 113 in Jhon Zambrano
# Processing Image - 114 in Jhon Zambrano
# Processing Image - 115 in Jhon Zambrano
# Processing Image - 116 in Jhon Zambrano
# Processing Image - 117 in Jhon Zambrano
# Processing Image - 118 in Jhon Zambrano
# Processing Image - 119 in Jhon Zambrano
# Processing Image - 120 in Jhon Zambrano
# Processing Image - 121 in Jhon Zambrano
# Processing Image - 122 in Jhon Zambrano
# Processing Image - 123 in Jhon Zambrano
# Processing Image - 124 in Jhon Zambrano
# Processing Image - 125 in Jhon Zambrano
# Processing Image - 126 in Jhon Zambrano
# Processing Image - 127 in Jhon Zambrano
# Processing Image - 128 in Jhon Zambrano
# Processing Image - 129 in Jhon Zambrano
# Processing Image - 130 in Jhon Zambrano
# Processing Image - 131 in Jhon Zambrano
# Processing Image - 132 in Jhon Zambrano
# Processing Image - 133 in Jhon Zambrano
# Processing Image - 134 in Jhon Zambrano
# Processing Image - 135 in Jhon Zambrano
# Processing Image - 136 in Jhon Zambrano
# Processing Image - 137 in Jhon Zambrano
# Processing Image - 138 in Jhon Zambrano
# Processing Image - 139 in Jhon Zambrano
# Processing Image - 140 in Jhon Zambrano
# Processing Image - 141 in Jhon Zambrano
# Processing Image - 1 in Jordan Espinosa
# Processing Image - 2 in Jordan Espinosa
# Processing Image - 3 in Jordan Espinosa
# Processing Image - 4 in Jordan Espinosa
# Processing Image - 5 in Jordan Espinosa
# Processing Image - 6 in Jordan Espinosa
# Processing Image - 7 in Jordan Espinosa
# Processing Image - 8 in Jordan Espinosa
# Processing Image - 9 in Jordan Espinosa
# Processing Image - 10 in Jordan Espinosa
# Processing Image - 11 in Jordan Espinosa
# Processing Image - 12 in Jordan Espinosa
# Processing Image - 13 in Jordan Espinosa
# Processing Image - 14 in Jordan Espinosa
# Processing Image - 15 in Jordan Espinosa
# Processing Image - 16 in Jordan Espinosa
# Processing Image - 17 in Jordan Espinosa
# Processing Image - 18 in Jordan Espinosa
# Processing Image - 19 in Jordan Espinosa
# Processing Image - 20 in Jordan Espinosa
# Processing Image - 21 in Jordan Espinosa
# Processing Image - 22 in Jordan Espinosa
# Processing Image - 23 in Jordan Espinosa
# Processing Image - 24 in Jordan Espinosa
# Processing Image - 25 in Jordan Espinosa
# Processing Image - 26 in Jordan Espinosa
# Processing Image - 27 in Jordan Espinosa
# Processing Image - 28 in Jordan Espinosa
# Processing Image - 29 in Jordan Espinosa
# Processing Image - 30 in Jordan Espinosa
# Processing Image - 31 in Jordan Espinosa
# Processing Image - 32 in Jordan Espinosa
# Processing Image - 33 in Jordan Espinosa
# Processing Image - 34 in Jordan Espinosa
# Processing Image - 35 in Jordan Espinosa
# Processing Image - 36 in Jordan Espinosa
# Processing Image - 37 in Jordan Espinosa
# Processing Image - 38 in Jordan Espinosa
# Processing Image - 39 in Jordan Espinosa
# Processing Image - 40 in Jordan Espinosa
# Processing Image - 41 in Jordan Espinosa
# Processing Image - 42 in Jordan Espinosa
# Processing Image - 43 in Jordan Espinosa
# Processing Image - 44 in Jordan Espinosa
# Processing Image - 45 in Jordan Espinosa
# Processing Image - 46 in Jordan Espinosa
# Processing Image - 47 in Jordan Espinosa
# Processing Image - 48 in Jordan Espinosa
# Processing Image - 49 in Jordan Espinosa
# Processing Image - 50 in Jordan Espinosa
# Processing Image - 51 in Jordan Espinosa
# Processing Image - 52 in Jordan Espinosa
# Processing Image - 53 in Jordan Espinosa
# Processing Image - 54 in Jordan Espinosa
# Processing Image - 55 in Jordan Espinosa
# Processing Image - 56 in Jordan Espinosa
# Processing Image - 57 in Jordan Espinosa
# Processing Image - 58 in Jordan Espinosa
# Processing Image - 59 in Jordan Espinosa
# Processing Image - 60 in Jordan Espinosa
# Processing Image - 61 in Jordan Espinosa
# Processing Image - 62 in Jordan Espinosa
# Processing Image - 63 in Jordan Espinosa
# Processing Image - 64 in Jordan Espinosa
# Processing Image - 65 in Jordan Espinosa
# Processing Image - 66 in Jordan Espinosa
# Processing Image - 67 in Jordan Espinosa
# Processing Image - 68 in Jordan Espinosa
# Processing Image - 69 in Jordan Espinosa
# Processing Image - 70 in Jordan Espinosa
# Processing Image - 71 in Jordan Espinosa
# Processing Image - 72 in Jordan Espinosa
# Processing Image - 73 in Jordan Espinosa
# Processing Image - 74 in Jordan Espinosa
# Processing Image - 75 in Jordan Espinosa
# Processing Image - 76 in Jordan Espinosa
# Processing Image - 77 in Jordan Espinosa
# Processing Image - 78 in Jordan Espinosa
# Processing Image - 79 in Jordan Espinosa
# Processing Image - 80 in Jordan Espinosa
# Processing Image - 81 in Jordan Espinosa
# Processing Image - 82 in Jordan Espinosa
# Processing Image - 83 in Jordan Espinosa
# Processing Image - 84 in Jordan Espinosa
# Processing Image - 85 in Jordan Espinosa
# Processing Image - 86 in Jordan Espinosa
# Processing Image - 87 in Jordan Espinosa
# Processing Image - 88 in Jordan Espinosa
# Processing Image - 1 in Jorge Borrero
# Processing Image - 2 in Jorge Borrero
# Processing Image - 3 in Jorge Borrero
# Processing Image - 4 in Jorge Borrero
# Processing Image - 5 in Jorge Borrero
# Processing Image - 6 in Jorge Borrero
# Processing Image - 7 in Jorge Borrero
# Processing Image - 8 in Jorge Borrero
# Processing Image - 9 in Jorge Borrero
# Processing Image - 10 in Jorge Borrero
# Processing Image - 11 in Jorge Borrero
# Processing Image - 12 in Jorge Borrero
# Processing Image - 13 in Jorge Borrero
# Processing Image - 14 in Jorge Borrero
# Processing Image - 15 in Jorge Borrero
# Processing Image - 16 in Jorge Borrero
# Processing Image - 17 in Jorge Borrero
# Processing Image - 18 in Jorge Borrero
# Processing Image - 19 in Jorge Borrero
# Processing Image - 20 in Jorge Borrero
# Processing Image - 21 in Jorge Borrero
# Processing Image - 22 in Jorge Borrero
# Processing Image - 23 in Jorge Borrero
# Processing Image - 24 in Jorge Borrero
# Processing Image - 25 in Jorge Borrero
# Processing Image - 26 in Jorge Borrero
# Processing Image - 27 in Jorge Borrero
# Processing Image - 28 in Jorge Borrero
# Processing Image - 29 in Jorge Borrero
# Processing Image - 30 in Jorge Borrero
# Processing Image - 31 in Jorge Borrero
# Processing Image - 32 in Jorge Borrero
# Processing Image - 33 in Jorge Borrero
# Processing Image - 1 in JoseRuiz
# Processing Image - 2 in JoseRuiz
# Processing Image - 3 in JoseRuiz
# Processing Image - 4 in JoseRuiz
# Processing Image - 5 in JoseRuiz
# Processing Image - 6 in JoseRuiz
# Processing Image - 7 in JoseRuiz
# Processing Image - 8 in JoseRuiz
# Processing Image - 9 in JoseRuiz
# Processing Image - 10 in JoseRuiz
# Processing Image - 11 in JoseRuiz
# Processing Image - 12 in JoseRuiz
# Processing Image - 13 in JoseRuiz
# Processing Image - 14 in JoseRuiz
# Processing Image - 15 in JoseRuiz
# Processing Image - 16 in JoseRuiz
# Processing Image - 17 in JoseRuiz
# Processing Image - 18 in JoseRuiz
# Processing Image - 19 in JoseRuiz
# Processing Image - 20 in JoseRuiz
# Processing Image - 21 in JoseRuiz
# Processing Image - 22 in JoseRuiz
# Processing Image - 23 in JoseRuiz
# Processing Image - 24 in JoseRuiz
# Processing Image - 25 in JoseRuiz
# Processing Image - 26 in JoseRuiz
# Processing Image - 27 in JoseRuiz
# Processing Image - 28 in JoseRuiz
# Processing Image - 29 in JoseRuiz
# Processing Image - 30 in JoseRuiz
# Processing Image - 31 in JoseRuiz
# Processing Image - 32 in JoseRuiz
# Processing Image - 33 in JoseRuiz
# Processing Image - 34 in JoseRuiz
# Processing Image - 35 in JoseRuiz
# Processing Image - 36 in JoseRuiz
# Processing Image - 37 in JoseRuiz
# Processing Image - 38 in JoseRuiz
# Processing Image - 39 in JoseRuiz
# Processing Image - 40 in JoseRuiz
# Processing Image - 41 in JoseRuiz
# Processing Image - 42 in JoseRuiz
# Processing Image - 43 in JoseRuiz
# Processing Image - 44 in JoseRuiz
# Processing Image - 45 in JoseRuiz
# Processing Image - 46 in JoseRuiz
# Processing Image - 47 in JoseRuiz
# Processing Image - 48 in JoseRuiz
# Processing Image - 49 in JoseRuiz
# Processing Image - 50 in JoseRuiz
# Processing Image - 51 in JoseRuiz
# Processing Image - 52 in JoseRuiz
# Processing Image - 53 in JoseRuiz
# Processing Image - 54 in JoseRuiz
# Processing Image - 55 in JoseRuiz
# Processing Image - 56 in JoseRuiz
# Processing Image - 57 in JoseRuiz
# Processing Image - 58 in JoseRuiz
# Processing Image - 59 in JoseRuiz
# Processing Image - 60 in JoseRuiz
# Processing Image - 61 in JoseRuiz
# Processing Image - 62 in JoseRuiz
# Processing Image - 63 in JoseRuiz
# Processing Image - 64 in JoseRuiz
# Processing Image - 65 in JoseRuiz
# Processing Image - 66 in JoseRuiz
# Processing Image - 67 in JoseRuiz
# Processing Image - 68 in JoseRuiz
# Processing Image - 69 in JoseRuiz
# Processing Image - 70 in JoseRuiz
# Processing Image - 71 in JoseRuiz
# Processing Image - 72 in JoseRuiz
# Processing Image - 73 in JoseRuiz
# Processing Image - 74 in JoseRuiz
# Processing Image - 75 in JoseRuiz
# Processing Image - 76 in JoseRuiz
# Processing Image - 77 in JoseRuiz
# Processing Image - 78 in JoseRuiz
# Processing Image - 79 in JoseRuiz
# Processing Image - 80 in JoseRuiz
# Processing Image - 81 in JoseRuiz
# Processing Image - 82 in JoseRuiz
# Processing Image - 83 in JoseRuiz
# Processing Image - 84 in JoseRuiz
# Processing Image - 85 in JoseRuiz
# Processing Image - 86 in JoseRuiz
# Processing Image - 1 in LucioCarlos
# Processing Image - 2 in LucioCarlos
# Processing Image - 3 in LucioCarlos
# Processing Image - 4 in LucioCarlos
# Processing Image - 5 in LucioCarlos
# Processing Image - 6 in LucioCarlos
# Processing Image - 7 in LucioCarlos
# Processing Image - 8 in LucioCarlos
# Processing Image - 9 in LucioCarlos
# Processing Image - 10 in LucioCarlos
# Processing Image - 11 in LucioCarlos
# Processing Image - 12 in LucioCarlos
# Processing Image - 13 in LucioCarlos
# Processing Image - 14 in LucioCarlos
# Processing Image - 15 in LucioCarlos
# Processing Image - 16 in LucioCarlos
# Processing Image - 17 in LucioCarlos
# Processing Image - 18 in LucioCarlos
# Processing Image - 19 in LucioCarlos
# Processing Image - 20 in LucioCarlos
# Processing Image - 21 in LucioCarlos
# Processing Image - 22 in LucioCarlos
# Processing Image - 23 in LucioCarlos
# Processing Image - 24 in LucioCarlos
# Processing Image - 25 in LucioCarlos
# Processing Image - 26 in LucioCarlos
# Processing Image - 27 in LucioCarlos
# Processing Image - 28 in LucioCarlos
# Processing Image - 29 in LucioCarlos
# Processing Image - 30 in LucioCarlos
# Processing Image - 31 in LucioCarlos
# Processing Image - 32 in LucioCarlos
# Processing Image - 33 in LucioCarlos
# Processing Image - 34 in LucioCarlos
# Processing Image - 35 in LucioCarlos
# Processing Image - 36 in LucioCarlos
# Processing Image - 37 in LucioCarlos
# Processing Image - 38 in LucioCarlos
# Processing Image - 39 in LucioCarlos
# Processing Image - 40 in LucioCarlos
# Processing Image - 41 in LucioCarlos
# Processing Image - 42 in LucioCarlos
# Processing Image - 43 in LucioCarlos
# Processing Image - 44 in LucioCarlos
# Processing Image - 45 in LucioCarlos
# Processing Image - 46 in LucioCarlos
# Processing Image - 47 in LucioCarlos
# Processing Image - 48 in LucioCarlos
# Processing Image - 49 in LucioCarlos
# Processing Image - 50 in LucioCarlos
# Processing Image - 51 in LucioCarlos
# Processing Image - 52 in LucioCarlos
# Processing Image - 53 in LucioCarlos
# Processing Image - 54 in LucioCarlos
# Processing Image - 55 in LucioCarlos
# Processing Image - 56 in LucioCarlos
# Processing Image - 57 in LucioCarlos
# Processing Image - 58 in LucioCarlos
# Processing Image - 59 in LucioCarlos
# Processing Image - 60 in LucioCarlos
# Processing Image - 61 in LucioCarlos
# Processing Image - 62 in LucioCarlos
# Processing Image - 63 in LucioCarlos
# Processing Image - 64 in LucioCarlos
# Processing Image - 65 in LucioCarlos
# Processing Image - 66 in LucioCarlos
# Processing Image - 67 in LucioCarlos
# Processing Image - 68 in LucioCarlos
# Processing Image - 69 in LucioCarlos
# Processing Image - 70 in LucioCarlos
# Processing Image - 71 in LucioCarlos
# Processing Image - 72 in LucioCarlos
# Processing Image - 73 in LucioCarlos
# Processing Image - 74 in LucioCarlos
# Processing Image - 75 in LucioCarlos
# Processing Image - 76 in LucioCarlos
# Processing Image - 77 in LucioCarlos
# Processing Image - 78 in LucioCarlos
# Processing Image - 79 in LucioCarlos
# Processing Image - 80 in LucioCarlos
# Processing Image - 81 in LucioCarlos
# Processing Image - 82 in LucioCarlos
# Processing Image - 83 in LucioCarlos
# Processing Image - 84 in LucioCarlos
# Processing Image - 85 in LucioCarlos
# Processing Image - 86 in LucioCarlos
# Processing Image - 87 in LucioCarlos
# Processing Image - 88 in LucioCarlos
# Processing Image - 89 in LucioCarlos
# Processing Image - 90 in LucioCarlos
# Processing Image - 91 in LucioCarlos
# Processing Image - 92 in LucioCarlos
# Processing Image - 93 in LucioCarlos
# Processing Image - 94 in LucioCarlos
# Processing Image - 95 in LucioCarlos
# Processing Image - 96 in LucioCarlos
# Processing Image - 97 in LucioCarlos
# Processing Image - 98 in LucioCarlos
# Processing Image - 99 in LucioCarlos
# Processing Image - 100 in LucioCarlos
# Processing Image - 101 in LucioCarlos
# Processing Image - 102 in LucioCarlos
# Processing Image - 103 in LucioCarlos
# Processing Image - 104 in LucioCarlos
# Processing Image - 105 in LucioCarlos
# Processing Image - 106 in LucioCarlos
# Processing Image - 107 in LucioCarlos
# Processing Image - 108 in LucioCarlos
# Processing Image - 109 in LucioCarlos
# Processing Image - 1 in MasacheFernando
# Processing Image - 2 in MasacheFernando
# Processing Image - 3 in MasacheFernando
# Processing Image - 4 in MasacheFernando
# Processing Image - 5 in MasacheFernando
# Processing Image - 6 in MasacheFernando
# Processing Image - 7 in MasacheFernando
# Processing Image - 8 in MasacheFernando
# Processing Image - 9 in MasacheFernando
# Processing Image - 10 in MasacheFernando
# Processing Image - 11 in MasacheFernando
# Processing Image - 12 in MasacheFernando
# Processing Image - 13 in MasacheFernando
# Processing Image - 14 in MasacheFernando
# Processing Image - 15 in MasacheFernando
# Processing Image - 16 in MasacheFernando
# Processing Image - 17 in MasacheFernando
# Processing Image - 18 in MasacheFernando
# Processing Image - 19 in MasacheFernando
# Processing Image - 20 in MasacheFernando
# Processing Image - 21 in MasacheFernando
# Processing Image - 22 in MasacheFernando
# Processing Image - 23 in MasacheFernando
# Processing Image - 24 in MasacheFernando
# Processing Image - 25 in MasacheFernando
# Processing Image - 26 in MasacheFernando
# Processing Image - 27 in MasacheFernando
# Processing Image - 28 in MasacheFernando
# Processing Image - 29 in MasacheFernando
# Processing Image - 30 in MasacheFernando
# Processing Image - 31 in MasacheFernando
# Processing Image - 32 in MasacheFernando
# Processing Image - 33 in MasacheFernando
# ...
# Processing Image - 25 in RivasSelena
# Processing Image - 26 in RivasSelena
# Processing Image - 27 in RivasSelena
# Processing Image - 28 in RivasSelena
# Processing Image - 29 in RivasSelena
# Processing Image - 30 in RivasSelena
# Processing Image - 31 in RivasSelena
# Processing Image - 32 in RivasSelena
# Processing Image - 33 in RivasSelena
# Processing Image - 34 in RivasSelena
# Processing Image - 35 in RivasSelena
# Processing Image - 36 in RivasSelena
# Processing Image - 37 in RivasSelena
# Processing Image - 38 in RivasSelena
# Processing Image - 39 in RivasSelena
# Processing Image - 40 in RivasSelena
# Processing Image - 41 in RivasSelena
# Processing Image - 42 in RivasSelena
# Processing Image - 43 in RivasSelena
# Processing Image - 44 in RivasSelena
# Processing Image - 45 in RivasSelena
# Processing Image - 46 in RivasSelena
# Processing Image - 47 in RivasSelena
# Processing Image - 48 in RivasSelena
# Processing Image - 49 in RivasSelena
# Processing Image - 50 in RivasSelena
# Processing Image - 51 in RivasSelena
# Processing Image - 52 in RivasSelena
# Processing Image - 53 in RivasSelena
# Processing Image - 54 in RivasSelena
# Processing Image - 55 in RivasSelena
# Processing Image - 56 in RivasSelena
# Processing Image - 57 in RivasSelena
# Processing Image - 58 in RivasSelena
# Processing Image - 59 in RivasSelena
# Processing Image - 60 in RivasSelena
# Processing Image - 61 in RivasSelena
# Processing Image - 62 in RivasSelena
# Processing Image - 63 in RivasSelena
# Processing Image - 64 in RivasSelena
# Processing Image - 65 in RivasSelena
# Processing Image - 66 in RivasSelena
# Processing Image - 67 in RivasSelena
# Processing Image - 68 in RivasSelena
# Processing Image - 69 in RivasSelena
# Processing Image - 70 in RivasSelena
# Processing Image - 71 in RivasSelena
# Processing Image - 72 in RivasSelena
# Processing Image - 73 in RivasSelena
# Processing Image - 74 in RivasSelena
# Processing Image - 75 in RivasSelena
# Processing Image - 76 in RivasSelena
# Processing Image - 77 in RivasSelena
# Processing Image - 78 in RivasSelena
# Processing Image - 79 in RivasSelena
# Processing Image - 80 in RivasSelena
# Processing Image - 81 in RivasSelena
# Processing Image - 82 in RivasSelena
# Processing Image - 83 in RivasSelena
# Processing Image - 84 in RivasSelena
# Processing Image - 85 in RivasSelena
# Processing Image - 86 in RivasSelena
# Processing Image - 87 in RivasSelena
# Processing Image - 88 in RivasSelena
# Processing Image - 89 in RivasSelena
# Processing Image - 90 in RivasSelena
# Processing Image - 91 in RivasSelena
# Processing Image - 92 in RivasSelena
# Processing Image - 93 in RivasSelena
# Processing Image - 94 in RivasSelena
# Processing Image - 95 in RivasSelena
# Processing Image - 96 in RivasSelena
# Processing Image - 97 in RivasSelena
# Processing Image - 98 in RivasSelena
# Processing Image - 99 in RivasSelena
# Processing Image - 100 in RivasSelena
# Processing Image - 101 in RivasSelena
# Processing Image - 102 in RivasSelena
# Processing Image - 103 in RivasSelena
# Processing Image - 104 in RivasSelena
# Processing Image - 105 in RivasSelena
# Processing Image - 106 in RivasSelena
# Processing Image - 107 in RivasSelena
# Processing Image - 108 in RivasSelena
# Processing Image - 109 in RivasSelena
# Processing Image - 110 in RivasSelena
# Processing Image - 111 in RivasSelena
# Processing Image - 112 in RivasSelena
# Processing Image - 113 in RivasSelena
# Processing Image - 114 in RivasSelena
# Processing Image - 115 in RivasSelena
# Processing Image - 116 in RivasSelena
# Processing Image - 117 in RivasSelena
# Processing Image - 118 in RivasSelena
# Processing Image - 119 in RivasSelena
# Processing Image - 120 in RivasSelena
# Processing Image - 1 in SalazarJohana
# Processing Image - 2 in SalazarJohana
# Processing Image - 3 in SalazarJohana
# Processing Image - 4 in SalazarJohana
# Processing Image - 5 in SalazarJohana
# Processing Image - 6 in SalazarJohana
# Processing Image - 7 in SalazarJohana
# Processing Image - 8 in SalazarJohana
# Processing Image - 9 in SalazarJohana
# Processing Image - 10 in SalazarJohana
# Processing Image - 11 in SalazarJohana
# Processing Image - 12 in SalazarJohana
# Processing Image - 13 in SalazarJohana
# Processing Image - 14 in SalazarJohana
# Processing Image - 15 in SalazarJohana
# Processing Image - 16 in SalazarJohana
# Processing Image - 17 in SalazarJohana
# Processing Image - 18 in SalazarJohana
# Processing Image - 19 in SalazarJohana
# Processing Image - 20 in SalazarJohana
# Processing Image - 21 in SalazarJohana
# Processing Image - 22 in SalazarJohana
# Processing Image - 23 in SalazarJohana
# Processing Image - 24 in SalazarJohana
# Processing Image - 25 in SalazarJohana
# Processing Image - 26 in SalazarJohana
# Processing Image - 27 in SalazarJohana
# Processing Image - 28 in SalazarJohana
# Processing Image - 29 in SalazarJohana
# Processing Image - 30 in SalazarJohana
# Processing Image - 31 in SalazarJohana
# Processing Image - 32 in SalazarJohana
# Processing Image - 33 in SalazarJohana
# Processing Image - 34 in SalazarJohana
# Processing Image - 35 in SalazarJohana
# Processing Image - 36 in SalazarJohana
# Processing Image - 37 in SalazarJohana
# Processing Image - 38 in SalazarJohana
# Processing Image - 39 in SalazarJohana
# Processing Image - 40 in SalazarJohana
# Processing Image - 41 in SalazarJohana
# Processing Image - 42 in SalazarJohana
# Processing Image - 43 in SalazarJohana
# Processing Image - 44 in SalazarJohana
# Processing Image - 45 in SalazarJohana
# Processing Image - 46 in SalazarJohana
# Processing Image - 47 in SalazarJohana
# Processing Image - 48 in SalazarJohana
# Processing Image - 49 in SalazarJohana
# Processing Image - 50 in SalazarJohana
# Processing Image - 51 in SalazarJohana
# Processing Image - 52 in SalazarJohana
# Processing Image - 53 in SalazarJohana
# Processing Image - 54 in SalazarJohana
# Processing Image - 55 in SalazarJohana
# Processing Image - 1 in Solano Wilmer
# Processing Image - 2 in Solano Wilmer
# Processing Image - 3 in Solano Wilmer
# Processing Image - 4 in Solano Wilmer
# Processing Image - 5 in Solano Wilmer
# Processing Image - 6 in Solano Wilmer
# Processing Image - 7 in Solano Wilmer
# Processing Image - 8 in Solano Wilmer
# Processing Image - 9 in Solano Wilmer
# Processing Image - 10 in Solano Wilmer
# Processing Image - 11 in Solano Wilmer
# Processing Image - 12 in Solano Wilmer
# Processing Image - 13 in Solano Wilmer
# Processing Image - 14 in Solano Wilmer
# Processing Image - 15 in Solano Wilmer
# Processing Image - 16 in Solano Wilmer
# Processing Image - 17 in Solano Wilmer
# Processing Image - 18 in Solano Wilmer
# Processing Image - 19 in Solano Wilmer
# Processing Image - 20 in Solano Wilmer
# Processing Image - 21 in Solano Wilmer
# Processing Image - 22 in Solano Wilmer
# Processing Image - 23 in Solano Wilmer
# Processing Image - 24 in Solano Wilmer
# Processing Image - 25 in Solano Wilmer
# Processing Image - 26 in Solano Wilmer
# Processing Image - 27 in Solano Wilmer
# Processing Image - 28 in Solano Wilmer
# Processing Image - 29 in Solano Wilmer
# Processing Image - 30 in Solano Wilmer
# Processing Image - 31 in Solano Wilmer
# Processing Image - 32 in Solano Wilmer
# Processing Image - 33 in Solano Wilmer
# Processing Image - 34 in Solano Wilmer
# Processing Image - 35 in Solano Wilmer
# Processing Image - 36 in Solano Wilmer
# Processing Image - 37 in Solano Wilmer
# Processing Image - 38 in Solano Wilmer
# Processing Image - 39 in Solano Wilmer
# Processing Image - 40 in Solano Wilmer
# Processing Image - 41 in Solano Wilmer
# Processing Image - 42 in Solano Wilmer
# Processing Image - 43 in Solano Wilmer
# Processing Image - 44 in Solano Wilmer
# Processing Image - 45 in Solano Wilmer
# Processing Image - 46 in Solano Wilmer
# Processing Image - 47 in Solano Wilmer
# Processing Image - 48 in Solano Wilmer
# Processing Image - 49 in Solano Wilmer
# Processing Image - 50 in Solano Wilmer
# Processing Image - 51 in Solano Wilmer
# Processing Image - 52 in Solano Wilmer
# Processing Image - 53 in Solano Wilmer
# Processing Image - 54 in Solano Wilmer
# Processing Image - 55 in Solano Wilmer
# Processing Image - 1 in SolorzanoBryan
# Processing Image - 2 in SolorzanoBryan
# Processing Image - 3 in SolorzanoBryan
# Processing Image - 4 in SolorzanoBryan
# Processing Image - 5 in SolorzanoBryan
# Processing Image - 6 in SolorzanoBryan
# Processing Image - 7 in SolorzanoBryan
# Processing Image - 8 in SolorzanoBryan
# Processing Image - 9 in SolorzanoBryan
# Processing Image - 10 in SolorzanoBryan
# Processing Image - 11 in SolorzanoBryan
# Processing Image - 12 in SolorzanoBryan
# Processing Image - 13 in SolorzanoBryan
# Processing Image - 14 in SolorzanoBryan
# Processing Image - 15 in SolorzanoBryan
# Processing Image - 16 in SolorzanoBryan
# Processing Image - 17 in SolorzanoBryan
# Processing Image - 18 in SolorzanoBryan
# Processing Image - 19 in SolorzanoBryan
# Processing Image - 20 in SolorzanoBryan
# Processing Image - 21 in SolorzanoBryan
# Processing Image - 22 in SolorzanoBryan
# Processing Image - 23 in SolorzanoBryan
# Processing Image - 24 in SolorzanoBryan
# Processing Image - 25 in SolorzanoBryan
# Processing Image - 26 in SolorzanoBryan
# Processing Image - 27 in SolorzanoBryan
# Processing Image - 28 in SolorzanoBryan
# Processing Image - 29 in SolorzanoBryan
# Processing Image - 30 in SolorzanoBryan
# Processing Image - 31 in SolorzanoBryan
# Processing Image - 32 in SolorzanoBryan
# Processing Image - 33 in SolorzanoBryan
# Processing Image - 34 in SolorzanoBryan
# Processing Image - 35 in SolorzanoBryan
# Processing Image - 36 in SolorzanoBryan
# Processing Image - 37 in SolorzanoBryan
# Processing Image - 38 in SolorzanoBryan
# Processing Image - 39 in SolorzanoBryan
# Processing Image - 40 in SolorzanoBryan
# Processing Image - 41 in SolorzanoBryan
# Processing Image - 42 in SolorzanoBryan
# Processing Image - 43 in SolorzanoBryan
# Processing Image - 44 in SolorzanoBryan
# Processing Image - 45 in SolorzanoBryan
# Processing Image - 46 in SolorzanoBryan
# Processing Image - 47 in SolorzanoBryan
# Processing Image - 48 in SolorzanoBryan
# Processing Image - 49 in SolorzanoBryan
# Processing Image - 50 in SolorzanoBryan
# Processing Image - 51 in SolorzanoBryan
# Processing Image - 52 in SolorzanoBryan
# Processing Image - 53 in SolorzanoBryan
# Processing Image - 54 in SolorzanoBryan
# Processing Image - 55 in SolorzanoBryan
# Processing Image - 56 in SolorzanoBryan
# Processing Image - 57 in SolorzanoBryan
# Processing Image - 58 in SolorzanoBryan
# Processing Image - 59 in SolorzanoBryan
# Processing Image - 60 in SolorzanoBryan
# Processing Image - 61 in SolorzanoBryan
# Processing Image - 62 in SolorzanoBryan
# Processing Image - 63 in SolorzanoBryan
# Processing Image - 64 in SolorzanoBryan
# Processing Image - 65 in SolorzanoBryan
# Processing Image - 66 in SolorzanoBryan
# Processing Image - 67 in SolorzanoBryan
# Processing Image - 68 in SolorzanoBryan
# Processing Image - 69 in SolorzanoBryan
# Processing Image - 70 in SolorzanoBryan
# Processing Image - 71 in SolorzanoBryan
# Processing Image - 72 in SolorzanoBryan
# Processing Image - 73 in SolorzanoBryan
# Processing Image - 74 in SolorzanoBryan
# Processing Image - 75 in SolorzanoBryan
# Processing Image - 76 in SolorzanoBryan
# Processing Image - 77 in SolorzanoBryan
# Processing Image - 78 in SolorzanoBryan
# Processing Image - 79 in SolorzanoBryan
# Processing Image - 80 in SolorzanoBryan
# Processing Image - 81 in SolorzanoBryan
# Processing Image - 82 in SolorzanoBryan
# Processing Image - 83 in SolorzanoBryan
# Processing Image - 84 in SolorzanoBryan
# Processing Image - 85 in SolorzanoBryan
# Processing Image - 86 in SolorzanoBryan
# Processing Image - 87 in SolorzanoBryan
# Processing Image - 88 in SolorzanoBryan
# Processing Image - 89 in SolorzanoBryan
# Processing Image - 90 in SolorzanoBryan
# Processing Image - 91 in SolorzanoBryan
# Processing Image - 92 in SolorzanoBryan
# Processing Image - 93 in SolorzanoBryan
# Processing Image - 94 in SolorzanoBryan
# Processing Image - 95 in SolorzanoBryan
# Processing Image - 96 in SolorzanoBryan
# Processing Image - 97 in SolorzanoBryan
# Processing Image - 98 in SolorzanoBryan
# Processing Image - 99 in SolorzanoBryan
# Processing Image - 1 in VinicioBorja
# Processing Image - 2 in VinicioBorja
# Processing Image - 3 in VinicioBorja
# Processing Image - 4 in VinicioBorja
# Processing Image - 5 in VinicioBorja
# Processing Image - 6 in VinicioBorja
# Processing Image - 7 in VinicioBorja
# Processing Image - 8 in VinicioBorja
# Processing Image - 9 in VinicioBorja
# Processing Image - 10 in VinicioBorja
# Processing Image - 11 in VinicioBorja
# Processing Image - 12 in VinicioBorja
# Processing Image - 13 in VinicioBorja
# Processing Image - 14 in VinicioBorja
# Processing Image - 15 in VinicioBorja
# Processing Image - 16 in VinicioBorja
# Processing Image - 17 in VinicioBorja
# Processing Image - 18 in VinicioBorja
# Processing Image - 19 in VinicioBorja
# Processing Image - 20 in VinicioBorja
# Processing Image - 21 in VinicioBorja
# Processing Image - 22 in VinicioBorja
# Processing Image - 23 in VinicioBorja
# Processing Image - 24 in VinicioBorja
# Processing Image - 25 in VinicioBorja
# Processing Image - 26 in VinicioBorja
# Processing Image - 27 in VinicioBorja
# Processing Image - 28 in VinicioBorja
# Processing Image - 29 in VinicioBorja
# Processing Image - 30 in VinicioBorja
# Processing Image - 31 in VinicioBorja
# Processing Image - 32 in VinicioBorja
# Processing Image - 33 in VinicioBorja
# Processing Image - 34 in VinicioBorja
# Processing Image - 35 in VinicioBorja
# Processing Image - 36 in VinicioBorja
# Processing Image - 37 in VinicioBorja
# Processing Image - 38 in VinicioBorja
# Processing Image - 39 in VinicioBorja
# Processing Image - 40 in VinicioBorja
# Processing Image - 41 in VinicioBorja
# Processing Image - 42 in VinicioBorja
# Processing Image - 43 in VinicioBorja
# Processing Image - 44 in VinicioBorja
# Processing Image - 45 in VinicioBorja
# Processing Image - 46 in VinicioBorja
# Processing Image - 47 in VinicioBorja
# Processing Image - 48 in VinicioBorja
# Processing Image - 49 in VinicioBorja
# Processing Image - 50 in VinicioBorja
# Processing Image - 51 in VinicioBorja
# Processing Image - 52 in VinicioBorja
# Processing Image - 53 in VinicioBorja
# Processing Image - 54 in VinicioBorja
# Processing Image - 55 in VinicioBorja
# Processing Image - 56 in VinicioBorja
# Processing Image - 57 in VinicioBorja
# Processing Image - 58 in VinicioBorja
# Processing Image - 59 in VinicioBorja
# Processing Image - 60 in VinicioBorja
# Processing Image - 61 in VinicioBorja
# Processing Image - 62 in VinicioBorja
# Processing Image - 63 in VinicioBorja
# Processing Image - 64 in VinicioBorja
# Processing Image - 65 in VinicioBorja
# Processing Image - 66 in VinicioBorja
# Processing Image - 67 in VinicioBorja
# Processing Image - 68 in VinicioBorja
# Processing Image - 69 in VinicioBorja
# Processing Image - 70 in VinicioBorja
# Processing Image - 71 in VinicioBorja
# Processing Image - 72 in VinicioBorja
# Processing Image - 73 in VinicioBorja
# Processing Image - 74 in VinicioBorja
# Processing Image - 75 in VinicioBorja
# Processing Image - 76 in VinicioBorja
# Processing Image - 77 in VinicioBorja
# Processing Image - 78 in VinicioBorja
# Processing Image - 79 in VinicioBorja
# Processing Image - 80 in VinicioBorja
# Processing Image - 81 in VinicioBorja
# Processing Image - 82 in VinicioBorja
# Processing Image - 83 in VinicioBorja
# Processing Image - 84 in VinicioBorja
# Processing Image - 85 in VinicioBorja
# Processing Image - 86 in VinicioBorja
# Processing Image - 87 in VinicioBorja
# Processing Image - 88 in VinicioBorja
# Processing Image - 89 in VinicioBorja
# Processing Image - 90 in VinicioBorja
# Processing Image - 91 in VinicioBorja
# Processing Image - 92 in VinicioBorja
# Processing Image - 93 in VinicioBorja
# Processing Image - 94 in VinicioBorja
# Processing Image - 95 in VinicioBorja
# Processing Image - 96 in VinicioBorja
# Processing Image - 97 in VinicioBorja
# Processing Image - 98 in VinicioBorja
# Processing Image - 99 in VinicioBorja
# Processing Image - 100 in VinicioBorja
# Processing Image - 101 in VinicioBorja
# Processing Image - 102 in VinicioBorja
# Processing Image - 103 in VinicioBorja
# Processing Image - 104 in VinicioBorja
# Processing Image - 105 in VinicioBorja
# Processing Image - 106 in VinicioBorja
# Processing Image - 107 in VinicioBorja
# Processing Image - 108 in VinicioBorja
# Processing Image - 109 in VinicioBorja
# Processing Image - 110 in VinicioBorja

# %% [markdown]
# ## Background Removal

# %%
images_path = "./Fotos_SinRuido"
class_names = os.listdir(images_path)
class_names.sort()
print(class_names)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'HectorCedenio', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MasacheFernando', 'MelanyLopez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMariaJose', 'PauteKevin', 'Raymond Davila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']

# %%
for class_name in class_names:
    cur_path = images_path + "/" + class_name
    cur_label = class_name
    i = 1

    for file in glob.glob(cur_path + "/*"):
        print("Processing Image - {} in {}".format(i, cur_label))
        # read the images path
        image = cv2.imread(file)
        # remove bg 
        output = remove(image)
        # save images
        save_path = './Fotos_RemovedBG/'+ cur_label
        cv2.imwrite(os.path.join(save_path , cur_label + '_' + str(i) + '.png'), output)
        

        # show loop update
        i += 1
# Out:
# Processing Image - 1 in Ariel Chabla
# Processing Image - 2 in Ariel Chabla
# Processing Image - 3 in Ariel Chabla
# Processing Image - 4 in Ariel Chabla
# Processing Image - 5 in Ariel Chabla
# Processing Image - 6 in Ariel Chabla
# Processing Image - 7 in Ariel Chabla
# Processing Image - 8 in Ariel Chabla
# Processing Image - 9 in Ariel Chabla
# Processing Image - 10 in Ariel Chabla
# Processing Image - 11 in Ariel Chabla
# Processing Image - 12 in Ariel Chabla
# Processing Image - 13 in Ariel Chabla
# Processing Image - 14 in Ariel Chabla
# Processing Image - 15 in Ariel Chabla
# Processing Image - 16 in Ariel Chabla
# Processing Image - 17 in Ariel Chabla
# Processing Image - 18 in Ariel Chabla
# Processing Image - 19 in Ariel Chabla
# Processing Image - 20 in Ariel Chabla
# Processing Image - 21 in Ariel Chabla
# Processing Image - 22 in Ariel Chabla
# Processing Image - 23 in Ariel Chabla
# Processing Image - 24 in Ariel Chabla
# Processing Image - 25 in Ariel Chabla
# Processing Image - 26 in Ariel Chabla
# Processing Image - 27 in Ariel Chabla
# Processing Image - 28 in Ariel Chabla
# Processing Image - 29 in Ariel Chabla
# Processing Image - 30 in Ariel Chabla
# Processing Image - 31 in Ariel Chabla
# Processing Image - 32 in Ariel Chabla
# Processing Image - 33 in Ariel Chabla
# Processing Image - 34 in Ariel Chabla
# Processing Image - 35 in Ariel Chabla
# Processing Image - 36 in Ariel Chabla
# Processing Image - 37 in Ariel Chabla
# Processing Image - 38 in Ariel Chabla
# Processing Image - 39 in Ariel Chabla
# Processing Image - 40 in Ariel Chabla
# Processing Image - 41 in Ariel Chabla
# Processing Image - 42 in Ariel Chabla
# Processing Image - 43 in Ariel Chabla
# Processing Image - 44 in Ariel Chabla
# Processing Image - 45 in Ariel Chabla
# Processing Image - 46 in Ariel Chabla
# Processing Image - 47 in Ariel Chabla
# Processing Image - 48 in Ariel Chabla
# Processing Image - 49 in Ariel Chabla
# Processing Image - 50 in Ariel Chabla
# Processing Image - 51 in Ariel Chabla
# Processing Image - 52 in Ariel Chabla
# Processing Image - 53 in Ariel Chabla
# Processing Image - 54 in Ariel Chabla
# Processing Image - 55 in Ariel Chabla
# Processing Image - 56 in Ariel Chabla
# Processing Image - 57 in Ariel Chabla
# Processing Image - 58 in Ariel Chabla
# Processing Image - 59 in Ariel Chabla
# Processing Image - 60 in Ariel Chabla
# Processing Image - 61 in Ariel Chabla
# Processing Image - 62 in Ariel Chabla
# Processing Image - 63 in Ariel Chabla
# Processing Image - 64 in Ariel Chabla
# Processing Image - 65 in Ariel Chabla
# Processing Image - 66 in Ariel Chabla
# Processing Image - 67 in Ariel Chabla
# Processing Image - 68 in Ariel Chabla
# Processing Image - 69 in Ariel Chabla
# Processing Image - 70 in Ariel Chabla
# Processing Image - 71 in Ariel Chabla
# Processing Image - 72 in Ariel Chabla
# Processing Image - 73 in Ariel Chabla
# Processing Image - 74 in Ariel Chabla
# Processing Image - 75 in Ariel Chabla
# Processing Image - 76 in Ariel Chabla
# Processing Image - 77 in Ariel Chabla
# Processing Image - 78 in Ariel Chabla
# Processing Image - 79 in Ariel Chabla
# Processing Image - 80 in Ariel Chabla
# Processing Image - 81 in Ariel Chabla
# Processing Image - 82 in Ariel Chabla
# Processing Image - 83 in Ariel Chabla
# Processing Image - 84 in Ariel Chabla
# Processing Image - 85 in Ariel Chabla
# Processing Image - 86 in Ariel Chabla
# Processing Image - 87 in Ariel Chabla
# Processing Image - 88 in Ariel Chabla
# Processing Image - 1 in ArroboMercy
# Processing Image - 2 in ArroboMercy
# Processing Image - 3 in ArroboMercy
# Processing Image - 4 in ArroboMercy
# Processing Image - 5 in ArroboMercy
# Processing Image - 6 in ArroboMercy
# Processing Image - 7 in ArroboMercy
# Processing Image - 8 in ArroboMercy
# Processing Image - 9 in ArroboMercy
# Processing Image - 10 in ArroboMercy
# Processing Image - 11 in ArroboMercy
# Processing Image - 12 in ArroboMercy
# Processing Image - 13 in ArroboMercy
# Processing Image - 14 in ArroboMercy
# Processing Image - 15 in ArroboMercy
# Processing Image - 16 in ArroboMercy
# Processing Image - 17 in ArroboMercy
# Processing Image - 18 in ArroboMercy
# Processing Image - 19 in ArroboMercy
# Processing Image - 20 in ArroboMercy
# Processing Image - 21 in ArroboMercy
# Processing Image - 22 in ArroboMercy
# Processing Image - 23 in ArroboMercy
# Processing Image - 24 in ArroboMercy
# Processing Image - 25 in ArroboMercy
# Processing Image - 26 in ArroboMercy
# Processing Image - 27 in ArroboMercy
# Processing Image - 28 in ArroboMercy
# Processing Image - 29 in ArroboMercy
# Processing Image - 30 in ArroboMercy
# Processing Image - 31 in ArroboMercy
# Processing Image - 32 in ArroboMercy
# Processing Image - 33 in ArroboMercy
# Processing Image - 34 in ArroboMercy
# Processing Image - 35 in ArroboMercy
# Processing Image - 36 in ArroboMercy
# Processing Image - 37 in ArroboMercy
# Processing Image - 38 in ArroboMercy
# Processing Image - 39 in ArroboMercy
# Processing Image - 40 in ArroboMercy
# Processing Image - 41 in ArroboMercy
# Processing Image - 42 in ArroboMercy
# Processing Image - 43 in ArroboMercy
# Processing Image - 44 in ArroboMercy
# Processing Image - 45 in ArroboMercy
# Processing Image - 46 in ArroboMercy
# Processing Image - 47 in ArroboMercy
# Processing Image - 48 in ArroboMercy
# Processing Image - 49 in ArroboMercy
# Processing Image - 50 in ArroboMercy
# Processing Image - 51 in ArroboMercy
# Processing Image - 52 in ArroboMercy
# Processing Image - 53 in ArroboMercy
# Processing Image - 54 in ArroboMercy
# Processing Image - 55 in ArroboMercy
# Processing Image - 56 in ArroboMercy
# Processing Image - 57 in ArroboMercy
# Processing Image - 58 in ArroboMercy
# Processing Image - 59 in ArroboMercy
# Processing Image - 60 in ArroboMercy
# Processing Image - 61 in ArroboMercy
# Processing Image - 62 in ArroboMercy
# Processing Image - 63 in ArroboMercy
# Processing Image - 64 in ArroboMercy
# Processing Image - 65 in ArroboMercy
# Processing Image - 66 in ArroboMercy
# Processing Image - 67 in ArroboMercy
# Processing Image - 68 in ArroboMercy
# Processing Image - 69 in ArroboMercy
# Processing Image - 70 in ArroboMercy
# Processing Image - 71 in ArroboMercy
# Processing Image - 72 in ArroboMercy
# Processing Image - 73 in ArroboMercy
# Processing Image - 74 in ArroboMercy
# Processing Image - 75 in ArroboMercy
# Processing Image - 76 in ArroboMercy
# Processing Image - 77 in ArroboMercy
# Processing Image - 78 in ArroboMercy
# Processing Image - 79 in ArroboMercy
# Processing Image - 80 in ArroboMercy
# Processing Image - 81 in ArroboMercy
# Processing Image - 82 in ArroboMercy
# Processing Image - 83 in ArroboMercy
# Processing Image - 84 in ArroboMercy
# Processing Image - 85 in ArroboMercy
# Processing Image - 86 in ArroboMercy
# Processing Image - 87 in ArroboMercy
# Processing Image - 1 in BarraganSteven
# Processing Image - 2 in BarraganSteven
# Processing Image - 3 in BarraganSteven
# Processing Image - 4 in BarraganSteven
# Processing Image - 5 in BarraganSteven
# Processing Image - 6 in BarraganSteven
# Processing Image - 7 in BarraganSteven
# Processing Image - 8 in BarraganSteven
# Processing Image - 9 in BarraganSteven
# Processing Image - 10 in BarraganSteven
# Processing Image - 11 in BarraganSteven
# Processing Image - 12 in BarraganSteven
# Processing Image - 13 in BarraganSteven
# Processing Image - 14 in BarraganSteven
# Processing Image - 15 in BarraganSteven
# Processing Image - 16 in BarraganSteven
# Processing Image - 17 in BarraganSteven
# Processing Image - 18 in BarraganSteven
# Processing Image - 19 in BarraganSteven
# Processing Image - 20 in BarraganSteven
# Processing Image - 21 in BarraganSteven
# Processing Image - 22 in BarraganSteven
# Processing Image - 23 in BarraganSteven
# Processing Image - 24 in BarraganSteven
# Processing Image - 25 in BarraganSteven
# Processing Image - 26 in BarraganSteven
# Processing Image - 27 in BarraganSteven
# Processing Image - 28 in BarraganSteven
# Processing Image - 29 in BarraganSteven
# Processing Image - 30 in BarraganSteven
# Processing Image - 31 in BarraganSteven
# Processing Image - 32 in BarraganSteven
# Processing Image - 33 in BarraganSteven
# Processing Image - 34 in BarraganSteven
# Processing Image - 35 in BarraganSteven
# Processing Image - 36 in BarraganSteven
# Processing Image - 37 in BarraganSteven
# Processing Image - 38 in BarraganSteven
# Processing Image - 39 in BarraganSteven
# Processing Image - 40 in BarraganSteven
# Processing Image - 41 in BarraganSteven
# Processing Image - 42 in BarraganSteven
# Processing Image - 43 in BarraganSteven
# Processing Image - 44 in BarraganSteven
# Processing Image - 45 in BarraganSteven
# Processing Image - 46 in BarraganSteven
# Processing Image - 47 in BarraganSteven
# Processing Image - 48 in BarraganSteven
# Processing Image - 49 in BarraganSteven
# Processing Image - 50 in BarraganSteven
# Processing Image - 51 in BarraganSteven
# Processing Image - 52 in BarraganSteven
# Processing Image - 53 in BarraganSteven
# Processing Image - 54 in BarraganSteven
# Processing Image - 55 in BarraganSteven
# Processing Image - 56 in BarraganSteven
# Processing Image - 57 in BarraganSteven
# Processing Image - 58 in BarraganSteven
# Processing Image - 59 in BarraganSteven
# Processing Image - 60 in BarraganSteven
# Processing Image - 61 in BarraganSteven
# Processing Image - 62 in BarraganSteven
# Processing Image - 63 in BarraganSteven
# Processing Image - 64 in BarraganSteven
# Processing Image - 65 in BarraganSteven
# Processing Image - 66 in BarraganSteven
# Processing Image - 67 in BarraganSteven
# Processing Image - 68 in BarraganSteven
# Processing Image - 69 in BarraganSteven
# Processing Image - 70 in BarraganSteven
# Processing Image - 71 in BarraganSteven
# Processing Image - 72 in BarraganSteven
# Processing Image - 73 in BarraganSteven
# Processing Image - 74 in BarraganSteven
# Processing Image - 75 in BarraganSteven
# Processing Image - 76 in BarraganSteven
# Processing Image - 77 in BarraganSteven
# Processing Image - 78 in BarraganSteven
# Processing Image - 79 in BarraganSteven
# Processing Image - 80 in BarraganSteven
# Processing Image - 81 in BarraganSteven
# Processing Image - 82 in BarraganSteven
# Processing Image - 83 in BarraganSteven
# Processing Image - 84 in BarraganSteven
# Processing Image - 85 in BarraganSteven
# Processing Image - 86 in BarraganSteven
# Processing Image - 87 in BarraganSteven
# Processing Image - 88 in BarraganSteven
# Processing Image - 89 in BarraganSteven
# Processing Image - 90 in BarraganSteven
# Processing Image - 91 in BarraganSteven
# Processing Image - 92 in BarraganSteven
# Processing Image - 93 in BarraganSteven
# Processing Image - 94 in BarraganSteven
# Processing Image - 95 in BarraganSteven
# Processing Image - 96 in BarraganSteven
# Processing Image - 97 in BarraganSteven
# Processing Image - 98 in BarraganSteven
# Processing Image - 99 in BarraganSteven
# Processing Image - 100 in BarraganSteven
# Processing Image - 101 in BarraganSteven
# Processing Image - 102 in BarraganSteven
# Processing Image - 103 in BarraganSteven
# Processing Image - 104 in BarraganSteven
# Processing Image - 105 in BarraganSteven
# Processing Image - 106 in BarraganSteven
# Processing Image - 107 in BarraganSteven
# Processing Image - 108 in BarraganSteven
# Processing Image - 109 in BarraganSteven
# Processing Image - 110 in BarraganSteven
# Processing Image - 111 in BarraganSteven
# Processing Image - 112 in BarraganSteven
# Processing Image - 113 in BarraganSteven
# Processing Image - 114 in BarraganSteven
# Processing Image - 115 in BarraganSteven
# Processing Image - 116 in BarraganSteven
# Processing Image - 117 in BarraganSteven
# Processing Image - 118 in BarraganSteven
# Processing Image - 119 in BarraganSteven
# Processing Image - 120 in BarraganSteven
# Processing Image - 121 in BarraganSteven
# Processing Image - 122 in BarraganSteven
# Processing Image - 123 in BarraganSteven
# Processing Image - 124 in BarraganSteven
# Processing Image - 125 in BarraganSteven
# Processing Image - 126 in BarraganSteven
# Processing Image - 127 in BarraganSteven
# Processing Image - 128 in BarraganSteven
# Processing Image - 129 in BarraganSteven
# Processing Image - 130 in BarraganSteven
# Processing Image - 131 in BarraganSteven
# Processing Image - 132 in BarraganSteven
# Processing Image - 133 in BarraganSteven
# Processing Image - 134 in BarraganSteven
# Processing Image - 135 in BarraganSteven
# Processing Image - 136 in BarraganSteven
# Processing Image - 137 in BarraganSteven
# Processing Image - 138 in BarraganSteven
# Processing Image - 139 in BarraganSteven
# Processing Image - 140 in BarraganSteven
# Processing Image - 141 in BarraganSteven
# Processing Image - 142 in BarraganSteven
# Processing Image - 143 in BarraganSteven
# Processing Image - 144 in BarraganSteven
# Processing Image - 145 in BarraganSteven
# Processing Image - 146 in BarraganSteven
# Processing Image - 147 in BarraganSteven
# Processing Image - 148 in BarraganSteven
# Processing Image - 149 in BarraganSteven
# Processing Image - 150 in BarraganSteven
# Processing Image - 151 in BarraganSteven
# Processing Image - 152 in BarraganSteven
# Processing Image - 153 in BarraganSteven
# Processing Image - 1 in CevallosJoan
# Processing Image - 2 in CevallosJoan
# Processing Image - 3 in CevallosJoan
# Processing Image - 4 in CevallosJoan
# Processing Image - 5 in CevallosJoan
# Processing Image - 6 in CevallosJoan
# Processing Image - 7 in CevallosJoan
# Processing Image - 8 in CevallosJoan
# Processing Image - 9 in CevallosJoan
# Processing Image - 10 in CevallosJoan
# Processing Image - 11 in CevallosJoan
# Processing Image - 12 in CevallosJoan
# Processing Image - 13 in CevallosJoan
# Processing Image - 14 in CevallosJoan
# Processing Image - 15 in CevallosJoan
# Processing Image - 16 in CevallosJoan
# Processing Image - 17 in CevallosJoan
# Processing Image - 18 in CevallosJoan
# Processing Image - 19 in CevallosJoan
# Processing Image - 20 in CevallosJoan
# Processing Image - 21 in CevallosJoan
# Processing Image - 22 in CevallosJoan
# Processing Image - 23 in CevallosJoan
# Processing Image - 24 in CevallosJoan
# Processing Image - 25 in CevallosJoan
# Processing Image - 26 in CevallosJoan
# Processing Image - 27 in CevallosJoan
# Processing Image - 28 in CevallosJoan
# Processing Image - 29 in CevallosJoan
# Processing Image - 30 in CevallosJoan
# Processing Image - 31 in CevallosJoan
# Processing Image - 32 in CevallosJoan
# Processing Image - 33 in CevallosJoan
# Processing Image - 34 in CevallosJoan
# Processing Image - 35 in CevallosJoan
# Processing Image - 36 in CevallosJoan
# Processing Image - 37 in CevallosJoan
# Processing Image - 38 in CevallosJoan
# Processing Image - 39 in CevallosJoan
# Processing Image - 40 in CevallosJoan
# Processing Image - 41 in CevallosJoan
# Processing Image - 42 in CevallosJoan
# Processing Image - 43 in CevallosJoan
# Processing Image - 44 in CevallosJoan
# Processing Image - 45 in CevallosJoan
# Processing Image - 46 in CevallosJoan
# Processing Image - 47 in CevallosJoan
# Processing Image - 48 in CevallosJoan
# Processing Image - 49 in CevallosJoan
# Processing Image - 50 in CevallosJoan
# Processing Image - 51 in CevallosJoan
# Processing Image - 52 in CevallosJoan
# Processing Image - 53 in CevallosJoan
# Processing Image - 54 in CevallosJoan
# Processing Image - 55 in CevallosJoan
# Processing Image - 56 in CevallosJoan
# Processing Image - 57 in CevallosJoan
# Processing Image - 58 in CevallosJoan
# Processing Image - 59 in CevallosJoan
# Processing Image - 60 in CevallosJoan
# Processing Image - 61 in CevallosJoan
# Processing Image - 62 in CevallosJoan
# Processing Image - 63 in CevallosJoan
# Processing Image - 64 in CevallosJoan
# Processing Image - 65 in CevallosJoan
# Processing Image - 66 in CevallosJoan
# Processing Image - 67 in CevallosJoan
# Processing Image - 68 in CevallosJoan
# Processing Image - 69 in CevallosJoan
# Processing Image - 70 in CevallosJoan
# Processing Image - 71 in CevallosJoan
# Processing Image - 72 in CevallosJoan
# Processing Image - 73 in CevallosJoan
# Processing Image - 74 in CevallosJoan
# Processing Image - 75 in CevallosJoan
# Processing Image - 76 in CevallosJoan
# Processing Image - 77 in CevallosJoan
# Processing Image - 78 in CevallosJoan
# Processing Image - 79 in CevallosJoan
# Processing Image - 80 in CevallosJoan
# Processing Image - 81 in CevallosJoan
# Processing Image - 82 in CevallosJoan
# Processing Image - 83 in CevallosJoan
# Processing Image - 84 in CevallosJoan
# Processing Image - 85 in CevallosJoan
# Processing Image - 86 in CevallosJoan
# Processing Image - 87 in CevallosJoan
# Processing Image - 88 in CevallosJoan
# Processing Image - 89 in CevallosJoan
# Processing Image - 90 in CevallosJoan
# Processing Image - 91 in CevallosJoan
# Processing Image - 92 in CevallosJoan
# Processing Image - 93 in CevallosJoan
# Processing Image - 94 in CevallosJoan
# Processing Image - 95 in CevallosJoan
# Processing Image - 96 in CevallosJoan
# Processing Image - 97 in CevallosJoan
# Processing Image - 98 in CevallosJoan
# Processing Image - 1 in EnriquezSelena
# Processing Image - 2 in EnriquezSelena
# Processing Image - 3 in EnriquezSelena
# Processing Image - 4 in EnriquezSelena
# Processing Image - 5 in EnriquezSelena
# Processing Image - 6 in EnriquezSelena
# Processing Image - 7 in EnriquezSelena
# Processing Image - 8 in EnriquezSelena
# Processing Image - 9 in EnriquezSelena
# Processing Image - 10 in EnriquezSelena
# Processing Image - 11 in EnriquezSelena
# Processing Image - 12 in EnriquezSelena
# Processing Image - 13 in EnriquezSelena
# Processing Image - 14 in EnriquezSelena
# Processing Image - 15 in EnriquezSelena
# Processing Image - 16 in EnriquezSelena
# Processing Image - 17 in EnriquezSelena
# Processing Image - 18 in EnriquezSelena
# Processing Image - 19 in EnriquezSelena
# Processing Image - 20 in EnriquezSelena
# Processing Image - 21 in EnriquezSelena
# Processing Image - 22 in EnriquezSelena
# Processing Image - 23 in EnriquezSelena
# Processing Image - 24 in EnriquezSelena
# Processing Image - 25 in EnriquezSelena
# Processing Image - 26 in EnriquezSelena
# Processing Image - 27 in EnriquezSelena
# Processing Image - 28 in EnriquezSelena
# Processing Image - 29 in EnriquezSelena
# Processing Image - 30 in EnriquezSelena
# Processing Image - 31 in EnriquezSelena
# Processing Image - 32 in EnriquezSelena
# Processing Image - 33 in EnriquezSelena
# Processing Image - 34 in EnriquezSelena
# Processing Image - 35 in EnriquezSelena
# Processing Image - 36 in EnriquezSelena
# Processing Image - 37 in EnriquezSelena
# Processing Image - 38 in EnriquezSelena
# Processing Image - 39 in EnriquezSelena
# Processing Image - 40 in EnriquezSelena
# Processing Image - 41 in EnriquezSelena
# Processing Image - 42 in EnriquezSelena
# Processing Image - 43 in EnriquezSelena
# Processing Image - 44 in EnriquezSelena
# Processing Image - 45 in EnriquezSelena
# Processing Image - 46 in EnriquezSelena
# Processing Image - 47 in EnriquezSelena
# Processing Image - 48 in EnriquezSelena
# Processing Image - 49 in EnriquezSelena
# Processing Image - 50 in EnriquezSelena
# Processing Image - 51 in EnriquezSelena
# Processing Image - 52 in EnriquezSelena
# Processing Image - 53 in EnriquezSelena
# Processing Image - 54 in EnriquezSelena
# Processing Image - 55 in EnriquezSelena
# Processing Image - 1 in GenesisHeredia
# Processing Image - 2 in GenesisHeredia
# Processing Image - 3 in GenesisHeredia
# Processing Image - 4 in GenesisHeredia
# Processing Image - 5 in GenesisHeredia
# Processing Image - 6 in GenesisHeredia
# Processing Image - 7 in GenesisHeredia
# Processing Image - 8 in GenesisHeredia
# Processing Image - 9 in GenesisHeredia
# Processing Image - 10 in GenesisHeredia
# Processing Image - 11 in GenesisHeredia
# Processing Image - 12 in GenesisHeredia
# Processing Image - 13 in GenesisHeredia
# Processing Image - 14 in GenesisHeredia
# Processing Image - 15 in GenesisHeredia
# Processing Image - 16 in GenesisHeredia
# Processing Image - 17 in GenesisHeredia
# Processing Image - 18 in GenesisHeredia
# Processing Image - 19 in GenesisHeredia
# Processing Image - 20 in GenesisHeredia
# Processing Image - 21 in GenesisHeredia
# Processing Image - 22 in GenesisHeredia
# Processing Image - 23 in GenesisHeredia
# Processing Image - 24 in GenesisHeredia
# Processing Image - 25 in GenesisHeredia
# Processing Image - 26 in GenesisHeredia
# Processing Image - 27 in GenesisHeredia
# Processing Image - 28 in GenesisHeredia
# Processing Image - 29 in GenesisHeredia
# Processing Image - 30 in GenesisHeredia
# Processing Image - 31 in GenesisHeredia
# Processing Image - 32 in GenesisHeredia
# Processing Image - 33 in GenesisHeredia
# Processing Image - 34 in GenesisHeredia
# Processing Image - 35 in GenesisHeredia
# Processing Image - 36 in GenesisHeredia
# Processing Image - 37 in GenesisHeredia
# Processing Image - 38 in GenesisHeredia
# Processing Image - 39 in GenesisHeredia
# Processing Image - 40 in GenesisHeredia
# Processing Image - 41 in GenesisHeredia
# Processing Image - 42 in GenesisHeredia
# Processing Image - 43 in GenesisHeredia
# Processing Image - 44 in GenesisHeredia
# Processing Image - 45 in GenesisHeredia
# Processing Image - 46 in GenesisHeredia
# Processing Image - 47 in GenesisHeredia
# Processing Image - 48 in GenesisHeredia
# Processing Image - 49 in GenesisHeredia
# Processing Image - 50 in GenesisHeredia
# Processing Image - 51 in GenesisHeredia
# Processing Image - 52 in GenesisHeredia
# Processing Image - 53 in GenesisHeredia
# Processing Image - 54 in GenesisHeredia
# Processing Image - 55 in GenesisHeredia
# Processing Image - 56 in GenesisHeredia
# Processing Image - 57 in GenesisHeredia
# Processing Image - 58 in GenesisHeredia
# Processing Image - 59 in GenesisHeredia
# Processing Image - 60 in GenesisHeredia
# Processing Image - 61 in GenesisHeredia
# Processing Image - 62 in GenesisHeredia
# Processing Image - 63 in GenesisHeredia
# Processing Image - 64 in GenesisHeredia
# Processing Image - 65 in GenesisHeredia
# Processing Image - 66 in GenesisHeredia
# Processing Image - 67 in GenesisHeredia
# Processing Image - 68 in GenesisHeredia
# Processing Image - 69 in GenesisHeredia
# Processing Image - 70 in GenesisHeredia
# Processing Image - 71 in GenesisHeredia
# Processing Image - 72 in GenesisHeredia
# Processing Image - 73 in GenesisHeredia
# Processing Image - 74 in GenesisHeredia
# Processing Image - 75 in GenesisHeredia
# Processing Image - 76 in GenesisHeredia
# Processing Image - 77 in GenesisHeredia
# Processing Image - 78 in GenesisHeredia
# Processing Image - 79 in GenesisHeredia
# Processing Image - 80 in GenesisHeredia
# Processing Image - 81 in GenesisHeredia
# Processing Image - 82 in GenesisHeredia
# Processing Image - 83 in GenesisHeredia
# Processing Image - 84 in GenesisHeredia
# Processing Image - 85 in GenesisHeredia
# Processing Image - 86 in GenesisHeredia
# Processing Image - 87 in GenesisHeredia
# Processing Image - 88 in GenesisHeredia
# Processing Image - 89 in GenesisHeredia
# Processing Image - 90 in GenesisHeredia
# Processing Image - 91 in GenesisHeredia
# Processing Image - 92 in GenesisHeredia
# Processing Image - 93 in GenesisHeredia
# Processing Image - 94 in GenesisHeredia
# Processing Image - 95 in GenesisHeredia
# Processing Image - 96 in GenesisHeredia
# Processing Image - 97 in GenesisHeredia
# Processing Image - 98 in GenesisHeredia
# Processing Image - 99 in GenesisHeredia
# Processing Image - 100 in GenesisHeredia
# Processing Image - 101 in GenesisHeredia
# Processing Image - 102 in GenesisHeredia
# Processing Image - 103 in GenesisHeredia
# Processing Image - 104 in GenesisHeredia
# Processing Image - 105 in GenesisHeredia
# Processing Image - 106 in GenesisHeredia
# Processing Image - 107 in GenesisHeredia
# Processing Image - 108 in GenesisHeredia
# Processing Image - 109 in GenesisHeredia
# Processing Image - 110 in GenesisHeredia
# Processing Image - 1 in GoyesAnthony
# Processing Image - 2 in GoyesAnthony
# Processing Image - 3 in GoyesAnthony
# Processing Image - 4 in GoyesAnthony
# Processing Image - 5 in GoyesAnthony
# Processing Image - 6 in GoyesAnthony
# Processing Image - 7 in GoyesAnthony
# Processing Image - 8 in GoyesAnthony
# Processing Image - 9 in GoyesAnthony
# Processing Image - 10 in GoyesAnthony
# Processing Image - 11 in GoyesAnthony
# Processing Image - 12 in GoyesAnthony
# Processing Image - 13 in GoyesAnthony
# Processing Image - 14 in GoyesAnthony
# Processing Image - 15 in GoyesAnthony
# Processing Image - 16 in GoyesAnthony
# Processing Image - 17 in GoyesAnthony
# Processing Image - 18 in GoyesAnthony
# Processing Image - 19 in GoyesAnthony
# Processing Image - 20 in GoyesAnthony
# Processing Image - 21 in GoyesAnthony
# Processing Image - 22 in GoyesAnthony
# Processing Image - 23 in GoyesAnthony
# Processing Image - 24 in GoyesAnthony
# Processing Image - 25 in GoyesAnthony
# Processing Image - 26 in GoyesAnthony
# Processing Image - 27 in GoyesAnthony
# Processing Image - 28 in GoyesAnthony
# Processing Image - 29 in GoyesAnthony
# Processing Image - 30 in GoyesAnthony
# Processing Image - 31 in GoyesAnthony
# Processing Image - 32 in GoyesAnthony
# Processing Image - 33 in GoyesAnthony
# Processing Image - 34 in GoyesAnthony
# Processing Image - 35 in GoyesAnthony
# Processing Image - 36 in GoyesAnthony
# Processing Image - 37 in GoyesAnthony
# Processing Image - 38 in GoyesAnthony
# Processing Image - 39 in GoyesAnthony
# Processing Image - 40 in GoyesAnthony
# Processing Image - 41 in GoyesAnthony
# Processing Image - 42 in GoyesAnthony
# Processing Image - 43 in GoyesAnthony
# Processing Image - 44 in GoyesAnthony
# Processing Image - 45 in GoyesAnthony
# Processing Image - 46 in GoyesAnthony
# Processing Image - 47 in GoyesAnthony
# Processing Image - 48 in GoyesAnthony
# Processing Image - 49 in GoyesAnthony
# Processing Image - 50 in GoyesAnthony
# Processing Image - 51 in GoyesAnthony
# Processing Image - 52 in GoyesAnthony
# Processing Image - 53 in GoyesAnthony
# Processing Image - 54 in GoyesAnthony
# Processing Image - 55 in GoyesAnthony
# Processing Image - 56 in GoyesAnthony
# Processing Image - 57 in GoyesAnthony
# Processing Image - 58 in GoyesAnthony
# Processing Image - 59 in GoyesAnthony
# Processing Image - 60 in GoyesAnthony
# Processing Image - 61 in GoyesAnthony
# Processing Image - 62 in GoyesAnthony
# Processing Image - 63 in GoyesAnthony
# Processing Image - 64 in GoyesAnthony
# Processing Image - 65 in GoyesAnthony
# Processing Image - 66 in GoyesAnthony
# Processing Image - 67 in GoyesAnthony
# Processing Image - 68 in GoyesAnthony
# Processing Image - 69 in GoyesAnthony
# Processing Image - 70 in GoyesAnthony
# Processing Image - 71 in GoyesAnthony
# Processing Image - 72 in GoyesAnthony
# Processing Image - 73 in GoyesAnthony
# Processing Image - 74 in GoyesAnthony
# Processing Image - 75 in GoyesAnthony
# Processing Image - 76 in GoyesAnthony
# Processing Image - 77 in GoyesAnthony
# Processing Image - 78 in GoyesAnthony
# Processing Image - 79 in GoyesAnthony
# Processing Image - 80 in GoyesAnthony
# Processing Image - 81 in GoyesAnthony
# Processing Image - 82 in GoyesAnthony
# Processing Image - 83 in GoyesAnthony
# Processing Image - 84 in GoyesAnthony
# Processing Image - 85 in GoyesAnthony
# Processing Image - 86 in GoyesAnthony
# Processing Image - 87 in GoyesAnthony
# Processing Image - 88 in GoyesAnthony
# Processing Image - 89 in GoyesAnthony
# Processing Image - 90 in GoyesAnthony
# Processing Image - 91 in GoyesAnthony
# Processing Image - 92 in GoyesAnthony
# Processing Image - 93 in GoyesAnthony
# Processing Image - 94 in GoyesAnthony
# Processing Image - 95 in GoyesAnthony
# Processing Image - 96 in GoyesAnthony
# Processing Image - 97 in GoyesAnthony
# Processing Image - 98 in GoyesAnthony
# Processing Image - 99 in GoyesAnthony
# Processing Image - 100 in GoyesAnthony
# Processing Image - 101 in GoyesAnthony
# Processing Image - 102 in GoyesAnthony
# Processing Image - 103 in GoyesAnthony
# Processing Image - 104 in GoyesAnthony
# Processing Image - 105 in GoyesAnthony
# Processing Image - 106 in GoyesAnthony
# Processing Image - 107 in GoyesAnthony
# Processing Image - 108 in GoyesAnthony
# Processing Image - 109 in GoyesAnthony
# Processing Image - 1 in HectorCedenio
# Processing Image - 2 in HectorCedenio
# Processing Image - 3 in HectorCedenio
# Processing Image - 4 in HectorCedenio
# Processing Image - 5 in HectorCedenio
# Processing Image - 6 in HectorCedenio
# Processing Image - 7 in HectorCedenio
# Processing Image - 8 in HectorCedenio
# Processing Image - 9 in HectorCedenio
# Processing Image - 10 in HectorCedenio
# Processing Image - 11 in HectorCedenio
# Processing Image - 12 in HectorCedenio
# Processing Image - 13 in HectorCedenio
# Processing Image - 14 in HectorCedenio
# Processing Image - 15 in HectorCedenio
# Processing Image - 16 in HectorCedenio
# Processing Image - 17 in HectorCedenio
# Processing Image - 18 in HectorCedenio
# Processing Image - 19 in HectorCedenio
# Processing Image - 20 in HectorCedenio
# Processing Image - 21 in HectorCedenio
# Processing Image - 22 in HectorCedenio
# Processing Image - 23 in HectorCedenio
# Processing Image - 24 in HectorCedenio
# Processing Image - 25 in HectorCedenio
# Processing Image - 26 in HectorCedenio
# Processing Image - 27 in HectorCedenio
# Processing Image - 28 in HectorCedenio
# Processing Image - 29 in HectorCedenio
# Processing Image - 30 in HectorCedenio
# Processing Image - 31 in HectorCedenio
# Processing Image - 32 in HectorCedenio
# Processing Image - 33 in HectorCedenio
# Processing Image - 34 in HectorCedenio
# Processing Image - 35 in HectorCedenio
# Processing Image - 36 in HectorCedenio
# Processing Image - 37 in HectorCedenio
# Processing Image - 38 in HectorCedenio
# Processing Image - 39 in HectorCedenio
# Processing Image - 40 in HectorCedenio
# Processing Image - 41 in HectorCedenio
# Processing Image - 42 in HectorCedenio
# Processing Image - 43 in HectorCedenio
# Processing Image - 44 in HectorCedenio
# Processing Image - 45 in HectorCedenio
# Processing Image - 46 in HectorCedenio
# Processing Image - 47 in HectorCedenio
# Processing Image - 48 in HectorCedenio
# Processing Image - 49 in HectorCedenio
# Processing Image - 50 in HectorCedenio
# Processing Image - 51 in HectorCedenio
# Processing Image - 52 in HectorCedenio
# Processing Image - 53 in HectorCedenio
# Processing Image - 54 in HectorCedenio
# Processing Image - 1 in Jhon Zambrano
# Processing Image - 2 in Jhon Zambrano
# Processing Image - 3 in Jhon Zambrano
# Processing Image - 4 in Jhon Zambrano
# Processing Image - 5 in Jhon Zambrano
# Processing Image - 6 in Jhon Zambrano
# Processing Image - 7 in Jhon Zambrano
# Processing Image - 8 in Jhon Zambrano
# Processing Image - 9 in Jhon Zambrano
# Processing Image - 10 in Jhon Zambrano
# Processing Image - 11 in Jhon Zambrano
# Processing Image - 12 in Jhon Zambrano
# Processing Image - 13 in Jhon Zambrano
# Processing Image - 14 in Jhon Zambrano
# Processing Image - 15 in Jhon Zambrano
# Processing Image - 16 in Jhon Zambrano
# Processing Image - 17 in Jhon Zambrano
# Processing Image - 18 in Jhon Zambrano
# Processing Image - 19 in Jhon Zambrano
# Processing Image - 20 in Jhon Zambrano
# Processing Image - 21 in Jhon Zambrano
# Processing Image - 22 in Jhon Zambrano
# Processing Image - 23 in Jhon Zambrano
# Processing Image - 24 in Jhon Zambrano
# Processing Image - 25 in Jhon Zambrano
# Processing Image - 26 in Jhon Zambrano
# Processing Image - 27 in Jhon Zambrano
# Processing Image - 28 in Jhon Zambrano
# Processing Image - 29 in Jhon Zambrano
# Processing Image - 30 in Jhon Zambrano
# Processing Image - 31 in Jhon Zambrano
# Processing Image - 32 in Jhon Zambrano
# Processing Image - 33 in Jhon Zambrano
# Processing Image - 34 in Jhon Zambrano
# Processing Image - 35 in Jhon Zambrano
# Processing Image - 36 in Jhon Zambrano
# Processing Image - 37 in Jhon Zambrano
# Processing Image - 38 in Jhon Zambrano
# Processing Image - 39 in Jhon Zambrano
# Processing Image - 40 in Jhon Zambrano
# Processing Image - 41 in Jhon Zambrano
# Processing Image - 42 in Jhon Zambrano
# Processing Image - 43 in Jhon Zambrano
# Processing Image - 44 in Jhon Zambrano
# Processing Image - 45 in Jhon Zambrano
# Processing Image - 46 in Jhon Zambrano
# Processing Image - 47 in Jhon Zambrano
# Processing Image - 48 in Jhon Zambrano
# Processing Image - 49 in Jhon Zambrano
# Processing Image - 50 in Jhon Zambrano
# Processing Image - 51 in Jhon Zambrano
# Processing Image - 52 in Jhon Zambrano
# Processing Image - 53 in Jhon Zambrano
# Processing Image - 54 in Jhon Zambrano
# Processing Image - 55 in Jhon Zambrano
# Processing Image - 56 in Jhon Zambrano
# Processing Image - 57 in Jhon Zambrano
# Processing Image - 58 in Jhon Zambrano
# Processing Image - 59 in Jhon Zambrano
# Processing Image - 60 in Jhon Zambrano
# Processing Image - 61 in Jhon Zambrano
# Processing Image - 62 in Jhon Zambrano
# Processing Image - 63 in Jhon Zambrano
# Processing Image - 64 in Jhon Zambrano
# Processing Image - 65 in Jhon Zambrano
# Processing Image - 66 in Jhon Zambrano
# Processing Image - 67 in Jhon Zambrano
# Processing Image - 68 in Jhon Zambrano
# Processing Image - 69 in Jhon Zambrano
# Processing Image - 70 in Jhon Zambrano
# Processing Image - 71 in Jhon Zambrano
# Processing Image - 72 in Jhon Zambrano
# Processing Image - 73 in Jhon Zambrano
# Processing Image - 74 in Jhon Zambrano
# Processing Image - 75 in Jhon Zambrano
# Processing Image - 76 in Jhon Zambrano
# Processing Image - 77 in Jhon Zambrano
# Processing Image - 78 in Jhon Zambrano
# Processing Image - 79 in Jhon Zambrano
# Processing Image - 80 in Jhon Zambrano
# Processing Image - 81 in Jhon Zambrano
# Processing Image - 82 in Jhon Zambrano
# Processing Image - 83 in Jhon Zambrano
# Processing Image - 84 in Jhon Zambrano
# Processing Image - 85 in Jhon Zambrano
# Processing Image - 86 in Jhon Zambrano
# Processing Image - 87 in Jhon Zambrano
# Processing Image - 88 in Jhon Zambrano
# Processing Image - 89 in Jhon Zambrano
# Processing Image - 90 in Jhon Zambrano
# Processing Image - 91 in Jhon Zambrano
# Processing Image - 92 in Jhon Zambrano
# Processing Image - 93 in Jhon Zambrano
# Processing Image - 94 in Jhon Zambrano
# Processing Image - 95 in Jhon Zambrano
# Processing Image - 96 in Jhon Zambrano
# Processing Image - 97 in Jhon Zambrano
# Processing Image - 98 in Jhon Zambrano
# Processing Image - 99 in Jhon Zambrano
# Processing Image - 100 in Jhon Zambrano
# Processing Image - 101 in Jhon Zambrano
# Processing Image - 102 in Jhon Zambrano
# Processing Image - 103 in Jhon Zambrano
# Processing Image - 104 in Jhon Zambrano
# Processing Image - 105 in Jhon Zambrano
# Processing Image - 106 in Jhon Zambrano
# Processing Image - 107 in Jhon Zambrano
# Processing Image - 108 in Jhon Zambrano
# Processing Image - 109 in Jhon Zambrano
# Processing Image - 110 in Jhon Zambrano
# Processing Image - 111 in Jhon Zambrano
# Processing Image - 112 in Jhon Zambrano
# Processing Image - 113 in Jhon Zambrano
# Processing Image - 114 in Jhon Zambrano
# Processing Image - 115 in Jhon Zambrano
# Processing Image - 116 in Jhon Zambrano
# Processing Image - 117 in Jhon Zambrano
# Processing Image - 118 in Jhon Zambrano
# Processing Image - 119 in Jhon Zambrano
# Processing Image - 120 in Jhon Zambrano
# Processing Image - 121 in Jhon Zambrano
# Processing Image - 122 in Jhon Zambrano
# Processing Image - 123 in Jhon Zambrano
# Processing Image - 124 in Jhon Zambrano
# Processing Image - 125 in Jhon Zambrano
# Processing Image - 126 in Jhon Zambrano
# Processing Image - 127 in Jhon Zambrano
# Processing Image - 128 in Jhon Zambrano
# Processing Image - 129 in Jhon Zambrano
# Processing Image - 130 in Jhon Zambrano
# Processing Image - 131 in Jhon Zambrano
# Processing Image - 132 in Jhon Zambrano
# Processing Image - 133 in Jhon Zambrano
# Processing Image - 134 in Jhon Zambrano
# Processing Image - 135 in Jhon Zambrano
# Processing Image - 136 in Jhon Zambrano
# Processing Image - 137 in Jhon Zambrano
# Processing Image - 138 in Jhon Zambrano
# Processing Image - 139 in Jhon Zambrano
# Processing Image - 140 in Jhon Zambrano
# Processing Image - 141 in Jhon Zambrano
# Processing Image - 1 in Jordan Espinosa
# Processing Image - 2 in Jordan Espinosa
# Processing Image - 3 in Jordan Espinosa
# Processing Image - 4 in Jordan Espinosa
# Processing Image - 5 in Jordan Espinosa
# Processing Image - 6 in Jordan Espinosa
# Processing Image - 7 in Jordan Espinosa
# Processing Image - 8 in Jordan Espinosa
# Processing Image - 9 in Jordan Espinosa
# Processing Image - 10 in Jordan Espinosa
# Processing Image - 11 in Jordan Espinosa
# Processing Image - 12 in Jordan Espinosa
# Processing Image - 13 in Jordan Espinosa
# Processing Image - 14 in Jordan Espinosa
# Processing Image - 15 in Jordan Espinosa
# Processing Image - 16 in Jordan Espinosa
# Processing Image - 17 in Jordan Espinosa
# Processing Image - 18 in Jordan Espinosa
# Processing Image - 19 in Jordan Espinosa
# Processing Image - 20 in Jordan Espinosa
# Processing Image - 21 in Jordan Espinosa
# Processing Image - 22 in Jordan Espinosa
# Processing Image - 23 in Jordan Espinosa
# Processing Image - 24 in Jordan Espinosa
# Processing Image - 25 in Jordan Espinosa
# Processing Image - 26 in Jordan Espinosa
# Processing Image - 27 in Jordan Espinosa
# Processing Image - 28 in Jordan Espinosa
# Processing Image - 29 in Jordan Espinosa
# Processing Image - 30 in Jordan Espinosa
# Processing Image - 31 in Jordan Espinosa
# Processing Image - 32 in Jordan Espinosa
# Processing Image - 33 in Jordan Espinosa
# Processing Image - 34 in Jordan Espinosa
# Processing Image - 35 in Jordan Espinosa
# Processing Image - 36 in Jordan Espinosa
# Processing Image - 37 in Jordan Espinosa
# Processing Image - 38 in Jordan Espinosa
# Processing Image - 39 in Jordan Espinosa
# Processing Image - 40 in Jordan Espinosa
# Processing Image - 41 in Jordan Espinosa
# Processing Image - 42 in Jordan Espinosa
# Processing Image - 43 in Jordan Espinosa
# Processing Image - 44 in Jordan Espinosa
# Processing Image - 45 in Jordan Espinosa
# Processing Image - 46 in Jordan Espinosa
# Processing Image - 47 in Jordan Espinosa
# Processing Image - 48 in Jordan Espinosa
# Processing Image - 49 in Jordan Espinosa
# Processing Image - 50 in Jordan Espinosa
# Processing Image - 51 in Jordan Espinosa
# Processing Image - 52 in Jordan Espinosa
# Processing Image - 53 in Jordan Espinosa
# Processing Image - 54 in Jordan Espinosa
# Processing Image - 55 in Jordan Espinosa
# Processing Image - 56 in Jordan Espinosa
# Processing Image - 57 in Jordan Espinosa
# Processing Image - 58 in Jordan Espinosa
# Processing Image - 59 in Jordan Espinosa
# Processing Image - 60 in Jordan Espinosa
# Processing Image - 61 in Jordan Espinosa
# Processing Image - 62 in Jordan Espinosa
# Processing Image - 63 in Jordan Espinosa
# Processing Image - 64 in Jordan Espinosa
# Processing Image - 65 in Jordan Espinosa
# Processing Image - 66 in Jordan Espinosa
# Processing Image - 67 in Jordan Espinosa
# Processing Image - 68 in Jordan Espinosa
# Processing Image - 69 in Jordan Espinosa
# Processing Image - 70 in Jordan Espinosa
# Processing Image - 71 in Jordan Espinosa
# Processing Image - 72 in Jordan Espinosa
# Processing Image - 73 in Jordan Espinosa
# Processing Image - 74 in Jordan Espinosa
# Processing Image - 75 in Jordan Espinosa
# Processing Image - 76 in Jordan Espinosa
# Processing Image - 77 in Jordan Espinosa
# Processing Image - 78 in Jordan Espinosa
# Processing Image - 79 in Jordan Espinosa
# Processing Image - 80 in Jordan Espinosa
# Processing Image - 81 in Jordan Espinosa
# Processing Image - 82 in Jordan Espinosa
# Processing Image - 83 in Jordan Espinosa
# Processing Image - 84 in Jordan Espinosa
# Processing Image - 85 in Jordan Espinosa
# Processing Image - 86 in Jordan Espinosa
# Processing Image - 87 in Jordan Espinosa
# Processing Image - 88 in Jordan Espinosa
# Processing Image - 1 in Jorge Borrero
# Processing Image - 2 in Jorge Borrero
# Processing Image - 3 in Jorge Borrero
# Processing Image - 4 in Jorge Borrero
# Processing Image - 5 in Jorge Borrero
# Processing Image - 6 in Jorge Borrero
# Processing Image - 7 in Jorge Borrero
# Processing Image - 8 in Jorge Borrero
# Processing Image - 9 in Jorge Borrero
# Processing Image - 10 in Jorge Borrero
# Processing Image - 11 in Jorge Borrero
# Processing Image - 12 in Jorge Borrero
# Processing Image - 13 in Jorge Borrero
# Processing Image - 14 in Jorge Borrero
# Processing Image - 15 in Jorge Borrero
# Processing Image - 16 in Jorge Borrero
# Processing Image - 17 in Jorge Borrero
# Processing Image - 18 in Jorge Borrero
# Processing Image - 19 in Jorge Borrero
# Processing Image - 20 in Jorge Borrero
# Processing Image - 21 in Jorge Borrero
# Processing Image - 22 in Jorge Borrero
# Processing Image - 23 in Jorge Borrero
# Processing Image - 24 in Jorge Borrero
# Processing Image - 25 in Jorge Borrero
# Processing Image - 26 in Jorge Borrero
# Processing Image - 27 in Jorge Borrero
# Processing Image - 28 in Jorge Borrero
# Processing Image - 29 in Jorge Borrero
# Processing Image - 30 in Jorge Borrero
# Processing Image - 31 in Jorge Borrero
# Processing Image - 32 in Jorge Borrero
# Processing Image - 33 in Jorge Borrero
# Processing Image - 1 in JoseRuiz
# Processing Image - 2 in JoseRuiz
# Processing Image - 3 in JoseRuiz
# Processing Image - 4 in JoseRuiz
# Processing Image - 5 in JoseRuiz
# Processing Image - 6 in JoseRuiz
# Processing Image - 7 in JoseRuiz
# Processing Image - 8 in JoseRuiz
# Processing Image - 9 in JoseRuiz
# Processing Image - 10 in JoseRuiz
# Processing Image - 11 in JoseRuiz
# Processing Image - 12 in JoseRuiz
# Processing Image - 13 in JoseRuiz
# Processing Image - 14 in JoseRuiz
# Processing Image - 15 in JoseRuiz
# Processing Image - 16 in JoseRuiz
# Processing Image - 17 in JoseRuiz
# Processing Image - 18 in JoseRuiz
# Processing Image - 19 in JoseRuiz
# Processing Image - 20 in JoseRuiz
# Processing Image - 21 in JoseRuiz
# Processing Image - 22 in JoseRuiz
# Processing Image - 23 in JoseRuiz
# Processing Image - 24 in JoseRuiz
# Processing Image - 25 in JoseRuiz
# Processing Image - 26 in JoseRuiz
# Processing Image - 27 in JoseRuiz
# Processing Image - 28 in JoseRuiz
# Processing Image - 29 in JoseRuiz
# Processing Image - 30 in JoseRuiz
# Processing Image - 31 in JoseRuiz
# Processing Image - 32 in JoseRuiz
# Processing Image - 33 in JoseRuiz
# Processing Image - 34 in JoseRuiz
# Processing Image - 35 in JoseRuiz
# Processing Image - 36 in JoseRuiz
# Processing Image - 37 in JoseRuiz
# Processing Image - 38 in JoseRuiz
# Processing Image - 39 in JoseRuiz
# Processing Image - 40 in JoseRuiz
# Processing Image - 41 in JoseRuiz
# Processing Image - 42 in JoseRuiz
# Processing Image - 43 in JoseRuiz
# Processing Image - 44 in JoseRuiz
# Processing Image - 45 in JoseRuiz
# Processing Image - 46 in JoseRuiz
# Processing Image - 47 in JoseRuiz
# Processing Image - 48 in JoseRuiz
# Processing Image - 49 in JoseRuiz
# Processing Image - 50 in JoseRuiz
# Processing Image - 51 in JoseRuiz
# Processing Image - 52 in JoseRuiz
# Processing Image - 53 in JoseRuiz
# Processing Image - 54 in JoseRuiz
# Processing Image - 55 in JoseRuiz
# Processing Image - 56 in JoseRuiz
# Processing Image - 57 in JoseRuiz
# Processing Image - 58 in JoseRuiz
# Processing Image - 59 in JoseRuiz
# Processing Image - 60 in JoseRuiz
# Processing Image - 61 in JoseRuiz
# Processing Image - 62 in JoseRuiz
# Processing Image - 63 in JoseRuiz
# Processing Image - 64 in JoseRuiz
# Processing Image - 65 in JoseRuiz
# Processing Image - 66 in JoseRuiz
# Processing Image - 67 in JoseRuiz
# Processing Image - 68 in JoseRuiz
# Processing Image - 69 in JoseRuiz
# Processing Image - 70 in JoseRuiz
# Processing Image - 71 in JoseRuiz
# Processing Image - 72 in JoseRuiz
# Processing Image - 73 in JoseRuiz
# Processing Image - 74 in JoseRuiz
# Processing Image - 75 in JoseRuiz
# Processing Image - 76 in JoseRuiz
# Processing Image - 77 in JoseRuiz
# Processing Image - 78 in JoseRuiz
# Processing Image - 79 in JoseRuiz
# Processing Image - 80 in JoseRuiz
# Processing Image - 81 in JoseRuiz
# Processing Image - 82 in JoseRuiz
# Processing Image - 83 in JoseRuiz
# Processing Image - 84 in JoseRuiz
# Processing Image - 85 in JoseRuiz
# Processing Image - 86 in JoseRuiz
# Processing Image - 1 in LucioCarlos
# Processing Image - 2 in LucioCarlos
# Processing Image - 3 in LucioCarlos
# Processing Image - 4 in LucioCarlos
# Processing Image - 5 in LucioCarlos
# Processing Image - 6 in LucioCarlos
# Processing Image - 7 in LucioCarlos
# Processing Image - 8 in LucioCarlos
# Processing Image - 9 in LucioCarlos
# Processing Image - 10 in LucioCarlos
# Processing Image - 11 in LucioCarlos
# Processing Image - 12 in LucioCarlos
# Processing Image - 13 in LucioCarlos
# Processing Image - 14 in LucioCarlos
# Processing Image - 15 in LucioCarlos
# Processing Image - 16 in LucioCarlos
# Processing Image - 17 in LucioCarlos
# Processing Image - 18 in LucioCarlos
# Processing Image - 19 in LucioCarlos
# Processing Image - 20 in LucioCarlos
# Processing Image - 21 in LucioCarlos
# Processing Image - 22 in LucioCarlos
# Processing Image - 23 in LucioCarlos
# Processing Image - 24 in LucioCarlos
# Processing Image - 25 in LucioCarlos
# Processing Image - 26 in LucioCarlos
# Processing Image - 27 in LucioCarlos
# Processing Image - 28 in LucioCarlos
# Processing Image - 29 in LucioCarlos
# Processing Image - 30 in LucioCarlos
# Processing Image - 31 in LucioCarlos
# Processing Image - 32 in LucioCarlos
# Processing Image - 33 in LucioCarlos
# Processing Image - 34 in LucioCarlos
# Processing Image - 35 in LucioCarlos
# Processing Image - 36 in LucioCarlos
# Processing Image - 37 in LucioCarlos
# Processing Image - 38 in LucioCarlos
# Processing Image - 39 in LucioCarlos
# Processing Image - 40 in LucioCarlos
# Processing Image - 41 in LucioCarlos
# Processing Image - 42 in LucioCarlos
# Processing Image - 43 in LucioCarlos
# Processing Image - 44 in LucioCarlos
# Processing Image - 45 in LucioCarlos
# Processing Image - 46 in LucioCarlos
# Processing Image - 47 in LucioCarlos
# Processing Image - 48 in LucioCarlos
# Processing Image - 49 in LucioCarlos
# Processing Image - 50 in LucioCarlos
# Processing Image - 51 in LucioCarlos
# Processing Image - 52 in LucioCarlos
# Processing Image - 53 in LucioCarlos
# Processing Image - 54 in LucioCarlos
# Processing Image - 55 in LucioCarlos
# Processing Image - 56 in LucioCarlos
# Processing Image - 57 in LucioCarlos
# Processing Image - 58 in LucioCarlos
# Processing Image - 59 in LucioCarlos
# Processing Image - 60 in LucioCarlos
# Processing Image - 61 in LucioCarlos
# Processing Image - 62 in LucioCarlos
# Processing Image - 63 in LucioCarlos
# Processing Image - 64 in LucioCarlos
# Processing Image - 65 in LucioCarlos
# Processing Image - 66 in LucioCarlos
# Processing Image - 67 in LucioCarlos
# Processing Image - 68 in LucioCarlos
# Processing Image - 69 in LucioCarlos
# Processing Image - 70 in LucioCarlos
# Processing Image - 71 in LucioCarlos
# Processing Image - 72 in LucioCarlos
# Processing Image - 73 in LucioCarlos
# Processing Image - 74 in LucioCarlos
# Processing Image - 75 in LucioCarlos
# Processing Image - 76 in LucioCarlos
# Processing Image - 77 in LucioCarlos
# Processing Image - 78 in LucioCarlos
# Processing Image - 79 in LucioCarlos
# Processing Image - 80 in LucioCarlos
# Processing Image - 81 in LucioCarlos
# Processing Image - 82 in LucioCarlos
# Processing Image - 83 in LucioCarlos
# Processing Image - 84 in LucioCarlos
# Processing Image - 85 in LucioCarlos
# Processing Image - 86 in LucioCarlos
# Processing Image - 87 in LucioCarlos
# Processing Image - 88 in LucioCarlos
# Processing Image - 89 in LucioCarlos
# Processing Image - 90 in LucioCarlos
# Processing Image - 91 in LucioCarlos
# Processing Image - 92 in LucioCarlos
# Processing Image - 93 in LucioCarlos
# Processing Image - 94 in LucioCarlos
# Processing Image - 95 in LucioCarlos
# Processing Image - 96 in LucioCarlos
# Processing Image - 97 in LucioCarlos
# Processing Image - 98 in LucioCarlos
# Processing Image - 99 in LucioCarlos
# Processing Image - 100 in LucioCarlos
# Processing Image - 101 in LucioCarlos
# Processing Image - 102 in LucioCarlos
# Processing Image - 103 in LucioCarlos
# Processing Image - 104 in LucioCarlos
# Processing Image - 105 in LucioCarlos
# Processing Image - 106 in LucioCarlos
# Processing Image - 107 in LucioCarlos
# Processing Image - 108 in LucioCarlos
# Processing Image - 109 in LucioCarlos
# Processing Image - 1 in MasacheFernando
# Processing Image - 2 in MasacheFernando
# Processing Image - 3 in MasacheFernando
# Processing Image - 4 in MasacheFernando
# Processing Image - 5 in MasacheFernando
# Processing Image - 6 in MasacheFernando
# Processing Image - 7 in MasacheFernando
# Processing Image - 8 in MasacheFernando
# Processing Image - 9 in MasacheFernando
# Processing Image - 10 in MasacheFernando
# Processing Image - 11 in MasacheFernando
# Processing Image - 12 in MasacheFernando
# Processing Image - 13 in MasacheFernando
# Processing Image - 14 in MasacheFernando
# Processing Image - 15 in MasacheFernando
# Processing Image - 16 in MasacheFernando
# Processing Image - 17 in MasacheFernando
# Processing Image - 18 in MasacheFernando
# Processing Image - 19 in MasacheFernando
# Processing Image - 20 in MasacheFernando
# Processing Image - 21 in MasacheFernando
# Processing Image - 22 in MasacheFernando
# Processing Image - 23 in MasacheFernando
# Processing Image - 24 in MasacheFernando
# Processing Image - 25 in MasacheFernando
# Processing Image - 26 in MasacheFernando
# Processing Image - 27 in MasacheFernando
# Processing Image - 28 in MasacheFernando
# Processing Image - 29 in MasacheFernando
# Processing Image - 30 in MasacheFernando
# Processing Image - 31 in MasacheFernando
# Processing Image - 32 in MasacheFernando
# Processing Image - 33 in MasacheFernando
# ...
# Processing Image - 25 in RivasSelena
# Processing Image - 26 in RivasSelena
# Processing Image - 27 in RivasSelena
# Processing Image - 28 in RivasSelena
# Processing Image - 29 in RivasSelena
# Processing Image - 30 in RivasSelena
# Processing Image - 31 in RivasSelena
# Processing Image - 32 in RivasSelena
# Processing Image - 33 in RivasSelena
# Processing Image - 34 in RivasSelena
# Processing Image - 35 in RivasSelena
# Processing Image - 36 in RivasSelena
# Processing Image - 37 in RivasSelena
# Processing Image - 38 in RivasSelena
# Processing Image - 39 in RivasSelena
# Processing Image - 40 in RivasSelena
# Processing Image - 41 in RivasSelena
# Processing Image - 42 in RivasSelena
# Processing Image - 43 in RivasSelena
# Processing Image - 44 in RivasSelena
# Processing Image - 45 in RivasSelena
# Processing Image - 46 in RivasSelena
# Processing Image - 47 in RivasSelena
# Processing Image - 48 in RivasSelena
# Processing Image - 49 in RivasSelena
# Processing Image - 50 in RivasSelena
# Processing Image - 51 in RivasSelena
# Processing Image - 52 in RivasSelena
# Processing Image - 53 in RivasSelena
# Processing Image - 54 in RivasSelena
# Processing Image - 55 in RivasSelena
# Processing Image - 56 in RivasSelena
# Processing Image - 57 in RivasSelena
# Processing Image - 58 in RivasSelena
# Processing Image - 59 in RivasSelena
# Processing Image - 60 in RivasSelena
# Processing Image - 61 in RivasSelena
# Processing Image - 62 in RivasSelena
# Processing Image - 63 in RivasSelena
# Processing Image - 64 in RivasSelena
# Processing Image - 65 in RivasSelena
# Processing Image - 66 in RivasSelena
# Processing Image - 67 in RivasSelena
# Processing Image - 68 in RivasSelena
# Processing Image - 69 in RivasSelena
# Processing Image - 70 in RivasSelena
# Processing Image - 71 in RivasSelena
# Processing Image - 72 in RivasSelena
# Processing Image - 73 in RivasSelena
# Processing Image - 74 in RivasSelena
# Processing Image - 75 in RivasSelena
# Processing Image - 76 in RivasSelena
# Processing Image - 77 in RivasSelena
# Processing Image - 78 in RivasSelena
# Processing Image - 79 in RivasSelena
# Processing Image - 80 in RivasSelena
# Processing Image - 81 in RivasSelena
# Processing Image - 82 in RivasSelena
# Processing Image - 83 in RivasSelena
# Processing Image - 84 in RivasSelena
# Processing Image - 85 in RivasSelena
# Processing Image - 86 in RivasSelena
# Processing Image - 87 in RivasSelena
# Processing Image - 88 in RivasSelena
# Processing Image - 89 in RivasSelena
# Processing Image - 90 in RivasSelena
# Processing Image - 91 in RivasSelena
# Processing Image - 92 in RivasSelena
# Processing Image - 93 in RivasSelena
# Processing Image - 94 in RivasSelena
# Processing Image - 95 in RivasSelena
# Processing Image - 96 in RivasSelena
# Processing Image - 97 in RivasSelena
# Processing Image - 98 in RivasSelena
# Processing Image - 99 in RivasSelena
# Processing Image - 100 in RivasSelena
# Processing Image - 101 in RivasSelena
# Processing Image - 102 in RivasSelena
# Processing Image - 103 in RivasSelena
# Processing Image - 104 in RivasSelena
# Processing Image - 105 in RivasSelena
# Processing Image - 106 in RivasSelena
# Processing Image - 107 in RivasSelena
# Processing Image - 108 in RivasSelena
# Processing Image - 109 in RivasSelena
# Processing Image - 110 in RivasSelena
# Processing Image - 111 in RivasSelena
# Processing Image - 112 in RivasSelena
# Processing Image - 113 in RivasSelena
# Processing Image - 114 in RivasSelena
# Processing Image - 115 in RivasSelena
# Processing Image - 116 in RivasSelena
# Processing Image - 117 in RivasSelena
# Processing Image - 118 in RivasSelena
# Processing Image - 119 in RivasSelena
# Processing Image - 120 in RivasSelena
# Processing Image - 1 in SalazarJohana
# Processing Image - 2 in SalazarJohana
# Processing Image - 3 in SalazarJohana
# Processing Image - 4 in SalazarJohana
# Processing Image - 5 in SalazarJohana
# Processing Image - 6 in SalazarJohana
# Processing Image - 7 in SalazarJohana
# Processing Image - 8 in SalazarJohana
# Processing Image - 9 in SalazarJohana
# Processing Image - 10 in SalazarJohana
# Processing Image - 11 in SalazarJohana
# Processing Image - 12 in SalazarJohana
# Processing Image - 13 in SalazarJohana
# Processing Image - 14 in SalazarJohana
# Processing Image - 15 in SalazarJohana
# Processing Image - 16 in SalazarJohana
# Processing Image - 17 in SalazarJohana
# Processing Image - 18 in SalazarJohana
# Processing Image - 19 in SalazarJohana
# Processing Image - 20 in SalazarJohana
# Processing Image - 21 in SalazarJohana
# Processing Image - 22 in SalazarJohana
# Processing Image - 23 in SalazarJohana
# Processing Image - 24 in SalazarJohana
# Processing Image - 25 in SalazarJohana
# Processing Image - 26 in SalazarJohana
# Processing Image - 27 in SalazarJohana
# Processing Image - 28 in SalazarJohana
# Processing Image - 29 in SalazarJohana
# Processing Image - 30 in SalazarJohana
# Processing Image - 31 in SalazarJohana
# Processing Image - 32 in SalazarJohana
# Processing Image - 33 in SalazarJohana
# Processing Image - 34 in SalazarJohana
# Processing Image - 35 in SalazarJohana
# Processing Image - 36 in SalazarJohana
# Processing Image - 37 in SalazarJohana
# Processing Image - 38 in SalazarJohana
# Processing Image - 39 in SalazarJohana
# Processing Image - 40 in SalazarJohana
# Processing Image - 41 in SalazarJohana
# Processing Image - 42 in SalazarJohana
# Processing Image - 43 in SalazarJohana
# Processing Image - 44 in SalazarJohana
# Processing Image - 45 in SalazarJohana
# Processing Image - 46 in SalazarJohana
# Processing Image - 47 in SalazarJohana
# Processing Image - 48 in SalazarJohana
# Processing Image - 49 in SalazarJohana
# Processing Image - 50 in SalazarJohana
# Processing Image - 51 in SalazarJohana
# Processing Image - 52 in SalazarJohana
# Processing Image - 53 in SalazarJohana
# Processing Image - 54 in SalazarJohana
# Processing Image - 55 in SalazarJohana
# Processing Image - 1 in Solano Wilmer
# Processing Image - 2 in Solano Wilmer
# Processing Image - 3 in Solano Wilmer
# Processing Image - 4 in Solano Wilmer
# Processing Image - 5 in Solano Wilmer
# Processing Image - 6 in Solano Wilmer
# Processing Image - 7 in Solano Wilmer
# Processing Image - 8 in Solano Wilmer
# Processing Image - 9 in Solano Wilmer
# Processing Image - 10 in Solano Wilmer
# Processing Image - 11 in Solano Wilmer
# Processing Image - 12 in Solano Wilmer
# Processing Image - 13 in Solano Wilmer
# Processing Image - 14 in Solano Wilmer
# Processing Image - 15 in Solano Wilmer
# Processing Image - 16 in Solano Wilmer
# Processing Image - 17 in Solano Wilmer
# Processing Image - 18 in Solano Wilmer
# Processing Image - 19 in Solano Wilmer
# Processing Image - 20 in Solano Wilmer
# Processing Image - 21 in Solano Wilmer
# Processing Image - 22 in Solano Wilmer
# Processing Image - 23 in Solano Wilmer
# Processing Image - 24 in Solano Wilmer
# Processing Image - 25 in Solano Wilmer
# Processing Image - 26 in Solano Wilmer
# Processing Image - 27 in Solano Wilmer
# Processing Image - 28 in Solano Wilmer
# Processing Image - 29 in Solano Wilmer
# Processing Image - 30 in Solano Wilmer
# Processing Image - 31 in Solano Wilmer
# Processing Image - 32 in Solano Wilmer
# Processing Image - 33 in Solano Wilmer
# Processing Image - 34 in Solano Wilmer
# Processing Image - 35 in Solano Wilmer
# Processing Image - 36 in Solano Wilmer
# Processing Image - 37 in Solano Wilmer
# Processing Image - 38 in Solano Wilmer
# Processing Image - 39 in Solano Wilmer
# Processing Image - 40 in Solano Wilmer
# Processing Image - 41 in Solano Wilmer
# Processing Image - 42 in Solano Wilmer
# Processing Image - 43 in Solano Wilmer
# Processing Image - 44 in Solano Wilmer
# Processing Image - 45 in Solano Wilmer
# Processing Image - 46 in Solano Wilmer
# Processing Image - 47 in Solano Wilmer
# Processing Image - 48 in Solano Wilmer
# Processing Image - 49 in Solano Wilmer
# Processing Image - 50 in Solano Wilmer
# Processing Image - 51 in Solano Wilmer
# Processing Image - 52 in Solano Wilmer
# Processing Image - 53 in Solano Wilmer
# Processing Image - 54 in Solano Wilmer
# Processing Image - 55 in Solano Wilmer
# Processing Image - 1 in SolorzanoBryan
# Processing Image - 2 in SolorzanoBryan
# Processing Image - 3 in SolorzanoBryan
# Processing Image - 4 in SolorzanoBryan
# Processing Image - 5 in SolorzanoBryan
# Processing Image - 6 in SolorzanoBryan
# Processing Image - 7 in SolorzanoBryan
# Processing Image - 8 in SolorzanoBryan
# Processing Image - 9 in SolorzanoBryan
# Processing Image - 10 in SolorzanoBryan
# Processing Image - 11 in SolorzanoBryan
# Processing Image - 12 in SolorzanoBryan
# Processing Image - 13 in SolorzanoBryan
# Processing Image - 14 in SolorzanoBryan
# Processing Image - 15 in SolorzanoBryan
# Processing Image - 16 in SolorzanoBryan
# Processing Image - 17 in SolorzanoBryan
# Processing Image - 18 in SolorzanoBryan
# Processing Image - 19 in SolorzanoBryan
# Processing Image - 20 in SolorzanoBryan
# Processing Image - 21 in SolorzanoBryan
# Processing Image - 22 in SolorzanoBryan
# Processing Image - 23 in SolorzanoBryan
# Processing Image - 24 in SolorzanoBryan
# Processing Image - 25 in SolorzanoBryan
# Processing Image - 26 in SolorzanoBryan
# Processing Image - 27 in SolorzanoBryan
# Processing Image - 28 in SolorzanoBryan
# Processing Image - 29 in SolorzanoBryan
# Processing Image - 30 in SolorzanoBryan
# Processing Image - 31 in SolorzanoBryan
# Processing Image - 32 in SolorzanoBryan
# Processing Image - 33 in SolorzanoBryan
# Processing Image - 34 in SolorzanoBryan
# Processing Image - 35 in SolorzanoBryan
# Processing Image - 36 in SolorzanoBryan
# Processing Image - 37 in SolorzanoBryan
# Processing Image - 38 in SolorzanoBryan
# Processing Image - 39 in SolorzanoBryan
# Processing Image - 40 in SolorzanoBryan
# Processing Image - 41 in SolorzanoBryan
# Processing Image - 42 in SolorzanoBryan
# Processing Image - 43 in SolorzanoBryan
# Processing Image - 44 in SolorzanoBryan
# Processing Image - 45 in SolorzanoBryan
# Processing Image - 46 in SolorzanoBryan
# Processing Image - 47 in SolorzanoBryan
# Processing Image - 48 in SolorzanoBryan
# Processing Image - 49 in SolorzanoBryan
# Processing Image - 50 in SolorzanoBryan
# Processing Image - 51 in SolorzanoBryan
# Processing Image - 52 in SolorzanoBryan
# Processing Image - 53 in SolorzanoBryan
# Processing Image - 54 in SolorzanoBryan
# Processing Image - 55 in SolorzanoBryan
# Processing Image - 56 in SolorzanoBryan
# Processing Image - 57 in SolorzanoBryan
# Processing Image - 58 in SolorzanoBryan
# Processing Image - 59 in SolorzanoBryan
# Processing Image - 60 in SolorzanoBryan
# Processing Image - 61 in SolorzanoBryan
# Processing Image - 62 in SolorzanoBryan
# Processing Image - 63 in SolorzanoBryan
# Processing Image - 64 in SolorzanoBryan
# Processing Image - 65 in SolorzanoBryan
# Processing Image - 66 in SolorzanoBryan
# Processing Image - 67 in SolorzanoBryan
# Processing Image - 68 in SolorzanoBryan
# Processing Image - 69 in SolorzanoBryan
# Processing Image - 70 in SolorzanoBryan
# Processing Image - 71 in SolorzanoBryan
# Processing Image - 72 in SolorzanoBryan
# Processing Image - 73 in SolorzanoBryan
# Processing Image - 74 in SolorzanoBryan
# Processing Image - 75 in SolorzanoBryan
# Processing Image - 76 in SolorzanoBryan
# Processing Image - 77 in SolorzanoBryan
# Processing Image - 78 in SolorzanoBryan
# Processing Image - 79 in SolorzanoBryan
# Processing Image - 80 in SolorzanoBryan
# Processing Image - 81 in SolorzanoBryan
# Processing Image - 82 in SolorzanoBryan
# Processing Image - 83 in SolorzanoBryan
# Processing Image - 84 in SolorzanoBryan
# Processing Image - 85 in SolorzanoBryan
# Processing Image - 86 in SolorzanoBryan
# Processing Image - 87 in SolorzanoBryan
# Processing Image - 88 in SolorzanoBryan
# Processing Image - 89 in SolorzanoBryan
# Processing Image - 90 in SolorzanoBryan
# Processing Image - 91 in SolorzanoBryan
# Processing Image - 92 in SolorzanoBryan
# Processing Image - 93 in SolorzanoBryan
# Processing Image - 94 in SolorzanoBryan
# Processing Image - 95 in SolorzanoBryan
# Processing Image - 96 in SolorzanoBryan
# Processing Image - 97 in SolorzanoBryan
# Processing Image - 98 in SolorzanoBryan
# Processing Image - 99 in SolorzanoBryan
# Processing Image - 1 in VinicioBorja
# Processing Image - 2 in VinicioBorja
# Processing Image - 3 in VinicioBorja
# Processing Image - 4 in VinicioBorja
# Processing Image - 5 in VinicioBorja
# Processing Image - 6 in VinicioBorja
# Processing Image - 7 in VinicioBorja
# Processing Image - 8 in VinicioBorja
# Processing Image - 9 in VinicioBorja
# Processing Image - 10 in VinicioBorja
# Processing Image - 11 in VinicioBorja
# Processing Image - 12 in VinicioBorja
# Processing Image - 13 in VinicioBorja
# Processing Image - 14 in VinicioBorja
# Processing Image - 15 in VinicioBorja
# Processing Image - 16 in VinicioBorja
# Processing Image - 17 in VinicioBorja
# Processing Image - 18 in VinicioBorja
# Processing Image - 19 in VinicioBorja
# Processing Image - 20 in VinicioBorja
# Processing Image - 21 in VinicioBorja
# Processing Image - 22 in VinicioBorja
# Processing Image - 23 in VinicioBorja
# Processing Image - 24 in VinicioBorja
# Processing Image - 25 in VinicioBorja
# Processing Image - 26 in VinicioBorja
# Processing Image - 27 in VinicioBorja
# Processing Image - 28 in VinicioBorja
# Processing Image - 29 in VinicioBorja
# Processing Image - 30 in VinicioBorja
# Processing Image - 31 in VinicioBorja
# Processing Image - 32 in VinicioBorja
# Processing Image - 33 in VinicioBorja
# Processing Image - 34 in VinicioBorja
# Processing Image - 35 in VinicioBorja
# Processing Image - 36 in VinicioBorja
# Processing Image - 37 in VinicioBorja
# Processing Image - 38 in VinicioBorja
# Processing Image - 39 in VinicioBorja
# Processing Image - 40 in VinicioBorja
# Processing Image - 41 in VinicioBorja
# Processing Image - 42 in VinicioBorja
# Processing Image - 43 in VinicioBorja
# Processing Image - 44 in VinicioBorja
# Processing Image - 45 in VinicioBorja
# Processing Image - 46 in VinicioBorja
# Processing Image - 47 in VinicioBorja
# Processing Image - 48 in VinicioBorja
# Processing Image - 49 in VinicioBorja
# Processing Image - 50 in VinicioBorja
# Processing Image - 51 in VinicioBorja
# Processing Image - 52 in VinicioBorja
# Processing Image - 53 in VinicioBorja
# Processing Image - 54 in VinicioBorja
# Processing Image - 55 in VinicioBorja
# Processing Image - 56 in VinicioBorja
# Processing Image - 57 in VinicioBorja
# Processing Image - 58 in VinicioBorja
# Processing Image - 59 in VinicioBorja
# Processing Image - 60 in VinicioBorja
# Processing Image - 61 in VinicioBorja
# Processing Image - 62 in VinicioBorja
# Processing Image - 63 in VinicioBorja
# Processing Image - 64 in VinicioBorja
# Processing Image - 65 in VinicioBorja
# Processing Image - 66 in VinicioBorja
# Processing Image - 67 in VinicioBorja
# Processing Image - 68 in VinicioBorja
# Processing Image - 69 in VinicioBorja
# Processing Image - 70 in VinicioBorja
# Processing Image - 71 in VinicioBorja
# Processing Image - 72 in VinicioBorja
# Processing Image - 73 in VinicioBorja
# Processing Image - 74 in VinicioBorja
# Processing Image - 75 in VinicioBorja
# Processing Image - 76 in VinicioBorja
# Processing Image - 77 in VinicioBorja
# Processing Image - 78 in VinicioBorja
# Processing Image - 79 in VinicioBorja
# Processing Image - 80 in VinicioBorja
# Processing Image - 81 in VinicioBorja
# Processing Image - 82 in VinicioBorja
# Processing Image - 83 in VinicioBorja
# Processing Image - 84 in VinicioBorja
# Processing Image - 85 in VinicioBorja
# Processing Image - 86 in VinicioBorja
# Processing Image - 87 in VinicioBorja
# Processing Image - 88 in VinicioBorja
# Processing Image - 89 in VinicioBorja
# Processing Image - 90 in VinicioBorja
# Processing Image - 91 in VinicioBorja
# Processing Image - 92 in VinicioBorja
# Processing Image - 93 in VinicioBorja
# Processing Image - 94 in VinicioBorja
# Processing Image - 95 in VinicioBorja
# Processing Image - 96 in VinicioBorja
# Processing Image - 97 in VinicioBorja
# Processing Image - 98 in VinicioBorja
# Processing Image - 99 in VinicioBorja
# Processing Image - 100 in VinicioBorja
# Processing Image - 101 in VinicioBorja
# Processing Image - 102 in VinicioBorja
# Processing Image - 103 in VinicioBorja
# Processing Image - 104 in VinicioBorja
# Processing Image - 105 in VinicioBorja
# Processing Image - 106 in VinicioBorja
# Processing Image - 107 in VinicioBorja
# Processing Image - 108 in VinicioBorja
# Processing Image - 109 in VinicioBorja
# Processing Image - 110 in VinicioBorja
